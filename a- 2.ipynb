# %% [markdown]
# # <span style="font-size:35px;color:#3665af">Section 1: MongoDB </span>
#
# <hr>
# In this section, we will practice how to use MongoDB. <br>
#
# ## Pre-reqs:
#
# You need to have your environment set up on Google Cloud working. Please refer to the provided Google Cloud instructions for this setup. <br>

# %% [markdown]
# <div style="font-size:30px;color:#3665af;background-color:#E9E9F5;padding:10px;">1. Environment Setup </div>
#
# <br>
#
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">1.1. Uploading your files to the cloud </div>
#
# We need to upload the file cities.txt to the bucket. In the following procedure we will refer to the bucket name as **bigdatasystem\_1234\_bucket** so you need to replace that with your bucket name.
#
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">1.2. Creating and uploading a Bucket </div>
#
# 1. Go to the cloud console.
# 2. Using the menu select Cloud Storage and then select your bucket. If you don't have one, you need to create one.
# 3. Drag your file to the bucket.
#
#
# ![Console](img/Storage.png)

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">1.3. Configuring a MongoDB Instance</div>
#
# Google cloud provides two ways to deploy a MongoDB instance. The first way is by creating a MongoDB Cluster. For this lab that option is too costly. The second one is by deploying a container. We will implement this latter approach.
#
# To do that, first open the Google Cloud console. Go to the web console and select your project, then click on the console icon on the top right corner.
#
# ![Console launcher](img/console.png)
#
# __ After you open your console, you should have something like this: __
# <hr>
#
# ![Console](img/console2.png)
#
# <br>
#
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">1.4. Pulling Docker image</div>
#
# To pull the docker image just type and run:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# gcloud docker -- pull launcher.gcr.io/google/mongodb3:latest
# </pre>
#
#
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">1.5. Creating the necessary directories</div>
#
# Just run:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# mkdir -p ~/mongo/data/shard1
# mkdir -p ~/mongo/files
# </pre>
#
# We need to pull the _cities.txt_ file from the bucket to the console.
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# gsutil cp gs://bigdatasystem_1234_bucket/cities.txt ~/mongo/files/cities.txt
# </pre>
#
# <div class="alert alert-block alert-info">
# <b>NOTE:</b> Remember to use your bucket name
# </div>

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">1.6. Running docker</div>
#
# To create a MongoDB instance just run this command.
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# docker run \
#   --name server1 \
#   -p 27017:27017 \
#   -v ~/mongo/data/shard1:/data/db \
#   -v ~/mongo/files:/files \
#   -d \
#   launcher.gcr.io/google/mongodb3
# </pre>
#
# - --name sets the name of the docker container
# - -p sets the port for MongoDB, in this case 27017
# - -v maps a host directory to the container; e.g. maps the ~/mongo/data/shard1 to the /data/db in the container
# - -d indicates the process to run in the container
#
#
# **Once you run this command, you should get an hexadecimal id of the image**.<br><br>
#
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">1.7. Docker Reference:</div>
#
# [Reference](https://docs.docker.com/) and [Cheat Sheet](https://github.com/wsargent/docker-cheat-sheet)
#
# #### To check which are the dockers containers currently executing
# Run:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# docker ps
# </pre>
#
# #### To stop a docker container
# Run:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# docker stop \<dockerName\>
# </pre>
# Example:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# docker stop server1
# </pre>
#
# #### To remove (destroy) a docker container
# Run:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# docker rm \<dockerName\>
# </pre>
# Example:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# docker rm server1
# </pre>

# %% [markdown]
# <div style="font-size:30px;color:#3665af;background-color:#E9E9F5;padding:10px;">2. Connecting to MongoDB </div>
#
#
# To execute the client run:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# docker exec -it server1 mongo admin
# </pre>
#
# You should get the following output:
#
# ![mongo client](img/mongoClient.png)
#
# To end the client just run:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px navy;">
# quit();
# </pre>

# %% [markdown]
# - Create the database **mydb** and the collection **cities**:
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px navy;">
# #Create the DB if not exists
# use mydb
# #Creates the collection.
# db.createCollection("cities")
# </pre>
#
# - Verify the existence of the database (mydb) and the database collection (cities):
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px navy;">
# show dbs
# show collections
# </pre>

# %% [markdown]
# <span style="color:RED">Paste the output of the previous four commands here. </span>

# %% [raw]
# srinath97gr@cloudshell:~ (bigdatasystems-fall2021-379815)$ docker exec -it server1 mongo admin
# MongoDB shell version v3.6.23
# connecting to: mongodb://127.0.0.1:27017/admin?gssapiServiceName=mongodb
# Implicit session: session { "id" : UUID("2c6a4b6a-ef18-422f-84ba-02264e128101") }
# MongoDB server version: 3.6.23
# Welcome to the MongoDB shell.
# For interactive help, type "help".
# For more comprehensive documentation, see
#         http://docs.mongodb.org/
# Questions? Try the support group
#         http://groups.google.com/group/mongodb-user
# Server has startup warnings:
# 2023-03-07T05:46:26.798+0000 I STORAGE  [initandlisten]
# 2023-03-07T05:46:26.799+0000 I STORAGE  [initandlisten] ** WARNING: Using the XFS filesystem is strongly recommended with the WiredTiger storage engine
# 2023-03-07T05:46:26.799+0000 I STORAGE  [initandlisten] **          See http://dochub.mongodb.org/core/prodnotes-filesystem
# 2023-03-07T05:46:27.499+0000 I CONTROL  [initandlisten]
# 2023-03-07T05:46:27.499+0000 I CONTROL  [initandlisten] ** WARNING: Access control is not enabled for the database.
# 2023-03-07T05:46:27.499+0000 I CONTROL  [initandlisten] **          Read and write access to data and configuration is unrestricted.
# 2023-03-07T05:46:27.499+0000 I CONTROL  [initandlisten]
# 2023-03-07T05:46:27.499+0000 I CONTROL  [initandlisten] ** WARNING: This server is bound to localhost.
# 2023-03-07T05:46:27.499+0000 I CONTROL  [initandlisten] **          Remote systems will be unable to connect to this server.
# 2023-03-07T05:46:27.499+0000 I CONTROL  [initandlisten] **          Start the server with --bind_ip <address> to specify which IP
# 2023-03-07T05:46:27.499+0000 I CONTROL  [initandlisten] **          addresses it should serve responses from, or with --bind_ip_all to
# 2023-03-07T05:46:27.499+0000 I CONTROL  [initandlisten] **          bind to all interfaces. If this behavior is desired, start the
# 2023-03-07T05:46:27.499+0000 I CONTROL  [initandlisten] **          server with --bind_ip 127.0.0.1 to disable this warning.
# 2023-03-07T05:46:27.499+0000 I CONTROL  [initandlisten]
# > use mydb
# switched to db mydb
# > db.createCollection("cities")
# { "ok" : 1 }
# > show dbs
# admin   0.000GB
# config  0.000GB
# local   0.000GB
# mydb    0.000GB
# > show collections
# cities
# > quit();
# srinath97gr@cloudshell:~ (bigdatasystems-fall2021-379815)$

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">2.1. Load some data</div>
#
#
# Quit the client so we can use the mongoimport to load data.
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px navy;">
# quit();
# </pre>
#
# - First let's check that we have the file in the correct directory.
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# ls -al ~/mongo/files
# </pre>
# Should list the cities.txt

# %% [markdown]
# - We will use the **mongoimport** tool to load documents from a text file. The syntax is:
# <pre style="background-color:#dddddd;padding:5px;">
# mongoimport  --db <database> --collection <collection> --file <filepath/filename>
# </pre>
#
# - So, to execute it through docker just run:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# docker exec -it server1 mongoimport  --db mydb --collection cities --file /files/cities.txt
# </pre>

# %% [markdown]
# <span style="color:RED">Paste the output here. </span>

# %% [raw]
# srinath97gr@cloudshell:~ (bigdatasystems-fall2021-379815)$ docker exec -it server1 mongoimport  --db mydb --collection cities --file /files/cities.txt
# 2023-03-07T06:51:43.343+0000    connected to: localhost
# 2023-03-07T06:51:43.719+0000    imported 29353 documents
# srinath97gr@cloudshell:~ (bigdatasystems-fall2021-379815)$

# %% [markdown]
# ### Question 1:
# In English describe the content of the database collection. Also, test the following command:
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px navy;">
# db.cities.find().pretty()
# </pre>
#
# <span style="color:RED">Include a sample of the result and your description of what that command does below.</span>

# %% [raw]
# # result
# > db.cities.find().pretty()
# {
#         "_id" : "01007",
#         "city" : "BELCHERTOWN",
#         "loc" : [
#                 -72.410953,
#                 42.275103
#         ],
#         "pop" : 10579,
#         "state" : "MA"
# }
# {
#         "_id" : "01002",
#         "city" : "CUSHMAN",
#         "loc" : [
#                 -72.51565,
#                 42.377017
#         ],
#         "pop" : 36963,
#         "state" : "MA"
# }
# {
#         "_id" : "01008",
#         "city" : "BLANDFORD",
#         "loc" : [
#                 -72.936114,
#                 42.182949
#         ],
#         "pop" : 1240,
#         "state" : "MA"
# }
# {
#         "_id" : "01010",
#         "city" : "BRIMFIELD",
#         "loc" : [
#                 -72.188455,
#                 42.116543
#         ],
#         "pop" : 3706,
#         "state" : "MA"
# }
# {
#         "_id" : "01011",
#         "city" : "CHESTER",
#         "loc" : [
#                 -72.988761,
#                 42.279421
#         ],
#         "pop" : 1688,
#         "state" : "MA"
# }
# {
#         "_id" : "01013",
#         "city" : "CHICOPEE",
#         "loc" : [
#                 -72.607962,
#                 42.162046
#         ],
#         "pop" : 23396,
#         "state" : "MA"
# }
# {
#         "_id" : "01012",
#         "city" : "CHESTERFIELD",
#         "loc" : [
#                 -72.833309,
#                 42.38167
#         ],
#         "pop" : 177,
#         "state" : "MA"
# }
# {
#         "_id" : "01001",
#         "city" : "AGAWAM",
#         "loc" : [
#                 -72.622739,
#                 42.070206
#         ],
#         "pop" : 15338,
#         "state" : "MA"
# }
# {
#         "_id" : "01022",
#         "city" : "WESTOVER AFB",
#         "loc" : [
#                 -72.558657,
#                 42.196672
#         ],
#         "pop" : 1764,
#         "state" : "MA"
# }
# {
#         "_id" : "01026",
#         "city" : "CUMMINGTON",
#         "loc" : [
#                 -72.905767,
#                 42.435296
#         ],
#         "pop" : 1484,
#         "state" : "MA"
# }
# {
#         "_id" : "01027",
#         "city" : "MOUNT TOM",
#         "loc" : [
#                 -72.679921,
#                 42.264319
#         ],
#         "pop" : 16864,
#         "state" : "MA"
# }
# {
#         "_id" : "01028",
#         "city" : "EAST LONGMEADOW",
#         "loc" : [
#                 -72.505565,
#                 42.067203
#         ],
#         "pop" : 13367,
#         "state" : "MA"
# }
# {
#         "_id" : "01030",
#         "city" : "FEEDING HILLS",
#         "loc" : [
#                 -72.675077,
#                 42.07182
#         ],
#         "pop" : 11985,
#         "state" : "MA"
# }
# {
#         "_id" : "01031",
#         "city" : "GILBERTVILLE",
#         "loc" : [
#                 -72.198585,
#                 42.332194
#         ],
#         "pop" : 2385,
#         "state" : "MA"
# }
# {
#         "_id" : "01005",
#         "city" : "BARRE",
#         "loc" : [
#                 -72.108354,
#                 42.409698
#         ],
#         "pop" : 4546,
#         "state" : "MA"
# }
# {
#         "_id" : "01034",
#         "city" : "TOLLAND",
#         "loc" : [
#                 -72.908793,
#                 42.070234
#         ],
#         "pop" : 1652,
#         "state" : "MA"
# }
# {
#         "_id" : "01035",
#         "city" : "HADLEY",
#         "loc" : [
#                 -72.571499,
#                 42.36062
#         ],
#         "pop" : 4231,
#         "state" : "MA"
# }
# {
#         "_id" : "01036",
#         "city" : "HAMPDEN",
#         "loc" : [
#                 -72.431823,
#                 42.064756
#         ],
#         "pop" : 4709,
#         "state" : "MA"
# }
# {
#         "_id" : "01032",
#         "city" : "GOSHEN",
#         "loc" : [
#                 -72.844092,
#                 42.466234
#         ],
#         "pop" : 122,
#         "state" : "MA"
# }
# {
#         "_id" : "01038",
#         "city" : "HATFIELD",
#         "loc" : [
#                 -72.616735,
#                 42.38439
#         ],
#         "pop" : 3184,
#         "state" : "MA"
# }
# Type "it" for more
#
#
# # The output of the above query is more and it is not all at once in goggle cloud shell. if we "it" after the result we will get some more result. If we need more result we need to press "it".
#
# #  The pretty() function is used to format the output of a query in a more readable way. It is used to format the output with indentation and line breaks, making it easier to read.

# %% [markdown]
# <hr style="border-top: 1px solid red; margin-top: 20px; margin-bottom: 1px"></hr>
#
# ##### Using what you learned in class and [MongoDB Reference]( https://www.mongodb.com/docs/v4.4/reference/mongo-shell/ ) answer the following queries using the cities collection.
#
# <hr style="border-top: 1px solid red; margin-top: 20px; margin-bottom: 1px"></hr>

# %% [markdown]
# ### Question 2:
# List all the cities of the State of Colorado.
#
# <span style="color:RED">Place your code and a sample of the result here.</span>

# %%
[
        "ARVADA",
        "AURORA",
        "BROOMFIELD",
        "WESTMINSTER",
        "COMMERCE CITY",
        "WHEAT RIDGE",
        "AGATE",
        "BENNETT",
        "BYERS",
        "LAFAYETTE",
        "LOUISVILLE",
        "ELIZABETH",
        "ELBERT",
        "CHERRY HILLS VIL",
        "ENGLEWOOD",
        "FRANKTOWN",
        "KIOWA",
        "LITTLETON",
        "CASTLE ROCK",
        "GREENWOOD VILLAG",
        "BOW MAR",
        "DEER TRAIL",
        "MONUMENT",
        "PALMER LAKE",
        "PARKER",
        "LARKSPUR",
        "STRASBURG",
        "WATKINS",
        "DECKERS",
        "HIGHLANDS RANCH",
        "DENVER",
        "LAKEWOOD",
        "FEDERAL HEIGHTS",
        "GLENDALE",
        "MOUNTAIN VIEW",
        "THORNTON",
        "NORTHGLENN",
        "EDGEWATER",
        "BOULDER",
        "GOLDEN",
        "BAILEY",
        "BLACK HAWK",
        "BOND",
        "CLARK",
        "CLIMAX",
        "COALMONT",
        "CONIFER",
        "FAIRPLAY",
        "FOXTON",
        "GRANBY",
        "GRAND LAKE",
        "IDAHO SPRINGS",
        "JAMESTOWN",
        "KEYSTONE",
        "EVERGREEN",
        "JEFFERSON",
        "MORRISON",
        "MC COY",
        "NEDERLAND",
        "OAK CREEK",
        "PARSHALL",
        "PINE",
        "PINECLIFFE",
        "KREMMLING",
        "LEADVILLE",
        "WARD",
        "STEAMBOAT SPRING",
        "WALDEN",
        "LONGMONT",
        "ALLENSPARK",
        "ROLLINSVILLE",
        "TOPONAS",
        "DRAKE",
        "ERIE",
        "ESTES PARK",
        "FORT COLLINS",
        "JOHNSTOWN",
        "LAPORTE",
        "VIRGINIA DALE",
        "LOVELAND",
        "BERTHOUD",
        "BELLVUE",
        "RED FEATHER LAKE",
        "MILLIKEN",
        "WELLINGTON",
        "WINDSOR",
        "LOCHBUI",
        "DACONO",
        "LYONS",
        "AULT",
        "BRIGGSDALE",
        "EATON",
        "EVANS",
        "CARR",
        "GARDEN CITY",
        "GREELEY",
        "WATTENBURG",
        "GALETON",
        "HUDSON",
        "KEENESBURG",
        "KERSEY",
        "GILL",
        "NUNN",
        "LA SALLE",
        "ORCHARD",
        "PLATTEVILLE",
        "ROGGEN",
        "WELDONA",
        "FORT MORGAN",
        "HOYT",
        "HENDERSON",
        "ATWOOD",
        "PIERCE",
        "AMHERST",
        "BRUSH",
        "FLEMING",
        "ECKLEY",
        "CROOK",
        "HILLROSE",
        "HOLYOKE",
        "HALE",
        "ILIFF",
        "JULESBURG",
        "LINDON",
        "GROVER",
        "HAXTUN",
        "AKRON",
        "NEW RAYMER",
        "WILLARD",
        "PEETZ",
        "OVID",
        "PADRONI",
        "SEDGWICK",
        "SNYDER",
        "STERLING",
        "OTIS",
        "VERNON",
        "STONEHAM",
        "ANTON",
        "YUMA",
        "ARAPAHOE",
        "ARRIBA",
        "BETHUNE",
        "LAST CHANCE",
        "BURLINGTON",
        "LAIRD",
        "CALHAN",
        "DIVIDE",
        "FLAGLER",
        "FLORISSANT",
        "FOUNTAIN",
        "CHEYENNE WELLS",
        "NORTH POLE",
        "GENOA",
        "HUGO",
        "GUFFEY",
        "KARVAL",
        "JOES",
        "COPE",
        "LIMON",
        "KIT CARSON",
        "MATHESON",
        "MANITOU SPRINGS",
        "RAMAH",
        "PEYTON",
        "RUSH",
        "KIRK",
        "STRATTON",
        "UNITED STATES AI",
        "LAKE GEORGE",
        "VONA",
        "WOODLAND PARK",
        "YODER",
        "COLORADO SPRINGS",
        "SIMLA",
        "SEIBERT",
        "FORT CARSON",
        "CHEYENNE MTN AFB",
        "PUEBLO",
        "PUEBLO WEST",
        "AGUILAR",
        "ARLINGTON",
        "BOONE",
        "NORTH AVONDALE",
        "BRANDON",
        "BRANSON",
        "BRISTOL",
        "CHIVINGTON",
        "CAMPO",
        "FARISITA",
        "GRANADA",
        "HARTMAN",
        "CADDOA",
        "HASWELL",
        "HOLLY",
        "BEULAH",
        "LAMAR",
        "DEORA",
        "CUCHARA",
        "MC CLAVE",
        "MANZANOLA",
        "DELHI",
        "OLNEY SPRINGS",
        "ORDWAY",
        "UTLEYVILLE",
        "FOWLER",
        "ROCKY FORD",
        "RYE",
        "TOWNER",
        "TIMPAS",
        "VILLEGREEN",
        "SPRINGFIELD",
        "SUGAR CITY",
        "JANSEN",
        "FARISTA",
        "VILAS",
        "WALSH",
        "WESTON",
        "ALAMOSA",
        "WILEY",
        "LYCAN",
        "BAYFIELD",
        "BLANCA",
        "CENTER",
        "ARBOLES",
        "CREEDE",
        "FORT GARLAND",
        "HOOPER",
        "LA GARITA",
        "TRINCHERA",
        "LA JARA",
        "MOFFAT",
        "IGNACIO",
        "ANTONITO",
        "MONTE VISTA",
        "MOSCA",
        "SAGUACHE",
        "SAN ACACIO",
        "PAGOSA SPRINGS",
        "SAN PABLO",
        "SOUTH FORK",
        "VILLA GROVE",
        "SALIDA",
        "BUENA VISTA",
        "ALMONT",
        "SANFORD",
        "MESITA",
        "FLORENCE",
        "GRANITE",
        "GUNNISON",
        "HOWARD",
        "LAKE CITY",
        "NATHROP",
        "PARLIN",
        "PENROSE",
        "PITKIN",
        "POWDERHORN",
        "CIMARRON",
        "TWIN LAKES",
        "WESTCLIFFE",
        "DURANGO",
        "WETMORE",
        "CAHONE",
        "CORTEZ",
        "DOLORES",
        "DOVE CREEK",
        "CRESTED BUTTE",
        "CANON CITY",
        "EGNAR",
        "HESPERUS",
        "MANCOS",
        "LEWIS",
        "PLEASANT VIEW",
        "AUSTIN",
        "BEDROCK",
        "YELLOW JACKET",
        "CEDAREDGE",
        "CRAWFORD",
        "DELTA",
        "MONTROSE",
        "ECKERT",
        "TOWAOC",
        "NORWOOD",
        "NUCLA",
        "OLATHE",
        "OURAY",
        "OPHIR",
        "PAONIA",
        "REDVALE",
        "RIDGWAY",
        "PLACERVILLE",
        "SILVERTON",
        "SOMERSET",
        "TELLURIDE",
        "GRAND JUNCTION",
        "FRUITVALE",
        "CLIFTON",
        "HOTCHKISS",
        "NATURITA",
        "FRUITA",
        "GATEWAY",
        "LOMA",
        "MACK",
        "PALISADE",
        "ASPEN",
        "GLENWOOD SPRINGS",
        "BASALT",
        "COLLBRAN",
        "MARBLE",
        "CRAIG",
        "DE BEQUE",
        "WHITEWATER",
        "BATTLEMENT MESA",
        "ELK SPRINGS",
        "GYPSUM",
        "HAMILTON",
        "HAYDEN",
        "MAYBELL",
        "DINOSAUR",
        "MESA",
        "MEREDITH",
        "NEW CASTLE",
        "RANGELY",
        "RIFLE",
        "SILT",
        "SLATER",
        "SNOWMASS",
        "EAGLE",
        "MEEKER",
        "VAIL"
]
>

# %% [markdown]
# ### Question 3:
# List the first 10 cities of the State of Colorado.
#
# <span style="color:RED">Place your code and a sample of the result here.</span>

# %%
> db.cities.find({state: "CO"}, {city: 1, _id: 0}).limit(10)
{ "city" : "ARVADA" }
{ "city" : "ARVADA" }
{ "city" : "ARVADA" }
{ "city" : "ARVADA" }
{ "city" : "AURORA" }
{ "city" : "AURORA" }
{ "city" : "AURORA" }
{ "city" : "AURORA" }
{ "city" : "AURORA" }
{ "city" : "AURORA" }

# %% [markdown]
# ### Question 4:
# List the 10 cities of the State of Colorado with largest populations.
#
# <span style="color:RED">Place your code and a sample of the result here.</span>

# %%
> db.cities.find({state: "CO"}, {city: 1, _id: 0}).sort({pop: -1}).limit(10)
{ "city" : "BOW MAR" }
{ "city" : "FEDERAL HEIGHTS" }
{ "city" : "GARDEN CITY" }
{ "city" : "DENVER" }
{ "city" : "LONGMONT" }
{ "city" : "AURORA" }
{ "city" : "WESTMINSTER" }
{ "city" : "CHERRY HILLS VIL" }
{ "city" : "BOULDER" }
{ "city" : "COLORADO SPRINGS" }

# %% [markdown]
# ### Question 5:
# List the 10 cities with largest populations.
#
# <span style="color:RED">Place your code and a sample of the result here.</span>

# %%
> db.cities.find({}, {city: 1, _id: 0}).sort({pop: -1}).limit(10)
{ "city" : "CHICAGO" }
{ "city" : "BROOKLYN" }
{ "city" : "NEW YORK" }
{ "city" : "NEW YORK" }
{ "city" : "BELL GARDENS" }
{ "city" : "CHICAGO" }
{ "city" : "LOS ANGELES" }
{ "city" : "CHICAGO" }
{ "city" : "CHICAGO" }
{ "city" : "NORWALK" }
>

# %% [markdown]
# <hr style="border: 1px double blue;" >
#
# ## Map-Reduce with MongoDB
#
# We can run map-reduce jobs on Mongodb. Let's count the number of cities per state:
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px navy;">
# db.cities.mapReduce(
#                     function()           { emit(this.state,1); },
#                     function(key,values) {return key,Array.sum(values);},
#                     { out: "citiesPerState" }
#                    )
# </pre>
#
# This code will generate a new collection instead of displaying the result.
# Use the commands discussed before to list the collections and to get the information from the new collection.

# %% [markdown]
# ### Question 6:
# <span style="color:RED">Place your code output (map-reduce) here.</span>

# %% [raw]
# > db.cities.mapReduce(
# ...                     function()           { emit(this.state,1); },
# ...                     function(key,values) {return key,Array.sum(values);},
# ...                     { out: "citiesPerState" }
# ...                    )
# {
#         "result" : "citiesPerState",
#         "timeMillis" : 230,
#         "counts" : {
#                 "input" : 29353,
#                 "emit" : 29353,
#                 "reduce" : 351,
#                 "output" : 51
#         },
#         "ok" : 1
# }
# >

# %% [markdown]
# ### Question 7:
# <span style="color:RED">Place the list of collections here.</span>

# %% [raw]
# > show collections
# cities
# citiesPerState

# %% [markdown]
# ### Question 8:
# <span style="color:RED">Place the content of the new collection here.</span>

# %% [raw]
# > db.citiesPerState.find()
# { "_id" : "AK", "value" : 195 }
# { "_id" : "AL", "value" : 567 }
# { "_id" : "AR", "value" : 578 }
# { "_id" : "AZ", "value" : 270 }
# { "_id" : "CA", "value" : 1516 }
# { "_id" : "CO", "value" : 414 }
# { "_id" : "CT", "value" : 263 }
# { "_id" : "DC", "value" : 24 }
# { "_id" : "DE", "value" : 53 }
# { "_id" : "FL", "value" : 804 }
# { "_id" : "GA", "value" : 635 }
# { "_id" : "HI", "value" : 80 }
# { "_id" : "IA", "value" : 922 }
# { "_id" : "ID", "value" : 244 }
# { "_id" : "IL", "value" : 1237 }
# { "_id" : "IN", "value" : 676 }
# { "_id" : "KS", "value" : 715 }
# { "_id" : "KY", "value" : 809 }
# { "_id" : "LA", "value" : 464 }
# { "_id" : "MA", "value" : 474 }
# Type "it" for more
# > it
# { "_id" : "MD", "value" : 420 }
# { "_id" : "ME", "value" : 410 }
# { "_id" : "MI", "value" : 876 }
# { "_id" : "MN", "value" : 882 }
# { "_id" : "MO", "value" : 994 }
# { "_id" : "MS", "value" : 363 }
# { "_id" : "MT", "value" : 314 }
# { "_id" : "NC", "value" : 705 }
# { "_id" : "ND", "value" : 391 }
# { "_id" : "NE", "value" : 574 }
# { "_id" : "NH", "value" : 218 }
# { "_id" : "NJ", "value" : 540 }
# { "_id" : "NM", "value" : 276 }
# { "_id" : "NV", "value" : 104 }
# { "_id" : "NY", "value" : 1595 }
# { "_id" : "OH", "value" : 1007 }
# { "_id" : "OK", "value" : 586 }
# { "_id" : "OR", "value" : 384 }
# { "_id" : "PA", "value" : 1458 }
# { "_id" : "RI", "value" : 69 }
# Type "it" for more
# >
#
# # The output of the above query is more and it is not all at once in goggle cloud shell. if we "it" after the result we will get some more result. If we need more result we need to press "it".

# %% [markdown]
# ### Map-Reduce - Question 9:
# Generate a collection called **populationPerState** that contains the population of each state.
#
# <span style="color:RED">Place your code, code output and a sample of the result here.</span>

# %% [raw]
# > db.cities.mapReduce(
# ...                     function()           { emit(this.state,this.pop); },
# ...                     function(key,values) {return key,Array.sum(values);},
# ...                     { out: "populationPerState" }
# ...                    )
# {
#         "result" : "populationPerState",
#         "timeMillis" : 184,
#         "counts" : {
#                 "input" : 29353,
#                 "emit" : 29353,
#                 "reduce" : 351,
#                 "output" : 51
#         },
#         "ok" : 1
# }
# > db.populationPerState.find()
# { "_id" : "AK", "value" : 544698 }
# { "_id" : "AL", "value" : 4040587 }
# { "_id" : "AR", "value" : 2350725 }
# { "_id" : "AZ", "value" : 3665228 }
# { "_id" : "CA", "value" : 29754890 }
# { "_id" : "CO", "value" : 3293755 }
# { "_id" : "CT", "value" : 3287116 }
# { "_id" : "DC", "value" : 606900 }
# { "_id" : "DE", "value" : 666168 }
# { "_id" : "FL", "value" : 12686644 }
# { "_id" : "GA", "value" : 6478216 }
# { "_id" : "HI", "value" : 1108229 }
# { "_id" : "IA", "value" : 2776420 }
# { "_id" : "ID", "value" : 1006749 }
# { "_id" : "IL", "value" : 11427576 }
# { "_id" : "IN", "value" : 5544136 }
# { "_id" : "KS", "value" : 2475285 }
# { "_id" : "KY", "value" : 3675484 }
# { "_id" : "LA", "value" : 4217595 }
# { "_id" : "MA", "value" : 6016425 }
# Type "it" for more
# > it
# { "_id" : "MD", "value" : 4781379 }
# { "_id" : "ME", "value" : 1226648 }
# { "_id" : "MI", "value" : 9295297 }
# { "_id" : "MN", "value" : 4372982 }
# { "_id" : "MO", "value" : 5110648 }
# { "_id" : "MS", "value" : 2573216 }
# { "_id" : "MT", "value" : 798948 }
# { "_id" : "NC", "value" : 6628637 }
# { "_id" : "ND", "value" : 638272 }
# { "_id" : "NE", "value" : 1578139 }
# { "_id" : "NH", "value" : 1109252 }
# { "_id" : "NJ", "value" : 7730188 }
# { "_id" : "NM", "value" : 1515069 }
# { "_id" : "NV", "value" : 1201833 }
# { "_id" : "NY", "value" : 17990402 }
# { "_id" : "OH", "value" : 10846517 }
# { "_id" : "OK", "value" : 3145585 }
# { "_id" : "OR", "value" : 2842321 }
# { "_id" : "PA", "value" : 11881643 }
# { "_id" : "RI", "value" : 1003218 }
# Type "it" for more
# > it
# { "_id" : "SC", "value" : 3486703 }
# { "_id" : "SD", "value" : 695397 }
# { "_id" : "TN", "value" : 4876457 }
# { "_id" : "TX", "value" : 16984601 }
# { "_id" : "UT", "value" : 1722850 }
# { "_id" : "VA", "value" : 6181479 }
# { "_id" : "VT", "value" : 562758 }
# { "_id" : "WA", "value" : 4866692 }
# { "_id" : "WI", "value" : 4891769 }
# { "_id" : "WV", "value" : 1793146 }
# { "_id" : "WY", "value" : 453528 }
# >

# %% [markdown]
# ### Map-Reduce - Question 10:
# Generate a collection called **totalPopulation** that contains the entire population of the USA.

# %% [markdown]
# <span style="color:RED">Place your code, code output and a sample of the result here.</span>
# > Hint: you can use your previous computed collection.

# %% [raw]
# > db.populationPerState.mapReduce(                      function()           { emit(this.id,this.value); },                      function(key,values) {return key,Array.sum(values);},                      { out: "totalPopulation" }                  )
# {
#         "result" : "totalPopulation",
#         "timeMillis" : 51,
#         "counts" : {
#                 "input" : 51,
#                 "emit" : 51,
#                 "reduce" : 1,
#                 "output" : 1
#         },
#         "ok" : 1
# }
# > db.totalPopulation.find()
# { "_id" : null, "value" : 248408400 }
# > db.totalPopulation.find(    { _id: null },    { value: 1, _id: 0 } )
# { "value" : 248408400 }
# >

# %% [markdown]
# <span style="text-align:center;font-size:30px;color:#2F632A">
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;STOP AND DELETE YOUR DOCKER WHEN YOU ARE FINISHED
# </span>
# <br>

# %% [markdown]
# <hr style="border-top: 5px solid purple; margin-top: 1px; margin-bottom: 1px"></hr>

# %% [markdown]
# # <span style="font-size:35px;color:#3665af">Section 2: REDIS </span>
# <hr>
#
# The objective of this part of the assignment is to introduce the use of REDIS (an in-memory data store) to collect data from various sources for subsequent data processing.
#
# For this assignment, we will be using REDIS on Google Cloud and Twitter Python libraries.
#
# <b><u>Notebook Layout (Table of contents):</u></b>
# 1. Environment Set-up
#    - Deployment a REDIS Cluster
#    - Network Configuration
#    - Enabling Remote Access
#    - Installing Python libraries
# 2. Getting Familiar with REDIS
# 3. Retrieving Information From Twitter
#    - Creating Twitter Credentials
#    - Accessing Twitter
#    - Saving Tweets to REDIS
#    - Retrieving Tweets from REDIS
# 4. Load Database From CSV

# %% [markdown]
# <div style="font-size:30px;color:#3665af;background-color:#E9E9F5;padding:10px;">1. Environment Setup </div>
#
# For this assignment we will be using the REDIS deployment on Google Cloud. Please follow the instructions to set up the cluster. You can opt to install REDIS on your own system. We don't recommend this approach though.<br><br>
#
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">1.1. Deployment of a REDIS Cluster </div>
#
# Use the search box, and search REDIS (Google Click to Deploy).
#
# <img src="img/redis_launcher.png" style="width:1000px;">
#
# We will deploy a REDIS cluster using three small-cpu nodes:
# - **Name**: redis-1
# - **Zone**: us-central1-f
# - **Instance Count**: 3
# - **Machine Type**: e2-small (2Gb memory)
# - **Boot Disk size**: 50GB
#
# All other parameters are set to default values. The cost of this deployment is the same as that of any other Virtual Machine (VM) created on the cloud. Your deployment configuration should be similar to this:<br>
#
# <img src="img/redis_deployment.png" style="width:1000px;">

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">1.2. Network Configuration </div>
#
# Once you have your cluster deployed, we need to setup a firewall rule to allow us access from our Jupyter-Notebook. To do that, go to the menu, and select **VPC Network**. Then select Firewall Rules and create a new rule as depicted below:
#
# <img src="img/vpc_network.png" style="width:1000px;">

# %% [markdown]
# <img src="img/fire_rule2.png" style="width:1000px;">

# %% [markdown]
# <img src="img/fire_rule2.png" style="width:1000px;">

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">
#     1.3. Enabling Remote Access to REDIS
# </div>
#
# After creating the firewall rule, we also need to configure REDIS to allow access from the external network. Follow this procedure to accomplish that:
#
# - Select the Compute Engine in the navigation menu
# - Open the SSH terminal to the main server, by selecting SSH on the _redis-1-db-vm-0_ VM (the Compute Engine menu on the Cloud).
#
# <img src="img/redis_vm.png" style="width:550px;">
#
# - Disable the REDIS password:
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# sudo nano /etc/redis/redis.conf
# </pre>
#
# Use your arrow keys to scroll down to the line beginning with "requirepass", then comment that line out using "#".
#
# Press ctrl+x, then hit y, then Enter.
#
# - Restart REDIS
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# sudo service redis-server restart
# </pre>
#
# - Launch the REDIS Client on the console
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# redis-cli
# </pre>
#
# - Within the client change the config to disable protected mode
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px navy;">
# CONFIG SET protected-mode no
# </pre>
# You should get an **OK** message. Then type:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px navy;">
# quit
# </pre>
#
# Once this is completed, we should be able to access REDIS through the public ip we get on the VM list
#
# <img src="img/redis_vm_ip.png" style="width:550px;">

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">
#     1.4. Installing Python Libraries
# </div>
#
# You need to install two libraries for this assignment:
# - REDIS library, and
# - Twitter library.
#
# - Within your notebook environment (click the jupyterhub logo on top left), open a new terminal (New -> Terminal), and run
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# pip install tweepy
# pip install redis
# </pre>

# %% [markdown]
# <div style="font-size:30px;color:#3665af;background-color:#E9E9F5;padding:10px;">
#     2. Getting Familiar with <b>REDIS</b>
# </div>
#
# You can read about the REDIS commands [here](https://redis.io/commands).

# %%
##Import the library
import redis

# %%
## Connect to the server
REDIS_SERVER = '34.30.22.117'
REDIS_PORT   = 6379
myRedis = redis.StrictRedis(host=REDIS_SERVER, port=REDIS_PORT, db=0)

# %%
## Dropping Everything we got on REDIS
display(myRedis.flushdb())
display(myRedis.flushall())
# Out:
# True
# True

# %%
print("I'm storing a value on the key 'myKey'")
display(myRedis.set('myKey', 'This is the key value'))
print("I'm reading the value of 'myKey' from REDIS")
display(myRedis.get('myKey'))
# Out:
# I'm storing a value on the key 'myKey'
# True
# I'm reading the value of 'myKey' from REDIS
# b'This is the key value'

# %%
print("I'm storing a List on REDIS")

print("Adding elements to the end of the list")
display(myRedis.rpush('weekdays','Tuesday'))
display(myRedis.rpush('weekdays','Wednesday'))
display(myRedis.rpush('weekdays','Thursday'))
display(myRedis.rpush('weekdays','Friday'))
print("Current List Length:", myRedis.llen('weekdays'))
display("Current Weekdays Content:",myRedis.lrange('weekdays',0,-1))


print("Adding elements to the beginning of the list")
display(myRedis.lpush('weekdays','Monday'))

print("Current List Length:", myRedis.llen('weekdays'))
display("Current Weekdays Content:",myRedis.lrange('weekdays',0,-1))
# Out:
# I'm storing a List on REDIS
# Adding elements to the end of the list
# 1
# 2
# 3
# 4
# Current List Length: 4
# 'Current Weekdays Content:'
# [b'Tuesday', b'Wednesday', b'Thursday', b'Friday']
# Adding elements to the beginning of the list
# 5
# Current List Length: 5
# 'Current Weekdays Content:'
# [b'Monday', b'Tuesday', b'Wednesday', b'Thursday', b'Friday']

# %%
print("I'm storing a HASH on REDIS")
print("- Remember that hashes can be used to store documents!")

#create a dictionary
user = {"Name"    :"myName", 
        "Company" :"myCompany", 
        "Address" :"myAddress", 
        "Location":"MyLocation"}

print ("Store to REDIS")
display(myRedis.hmset("userDictionary", user))

print ("Retrieve from REDIS")
display(myRedis.hgetall("userDictionary"))
# Out:
# I'm storing a HASH on REDIS
# - Remember that hashes can be used to store documents!
# Store to REDIS
# /tmp/ipykernel_26/2491477041.py:11: DeprecationWarning: Redis.hmset() is deprecated. Use Redis.hset() instead.
#   display(myRedis.hmset("userDictionary", user))
# True
# Retrieve from REDIS
# {b'Name': b'myName',
#  b'Company': b'myCompany',
#  b'Address': b'myAddress',
#  b'Location': b'MyLocation'}

# %% [markdown]
# <div style="font-size:30px;color:#3665af;background-color:#E9E9F5;padding:10px;">
#     3. Retrieving Information From Twitter</div>
# <br>
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">
#     3.1. Creating Twitter Credentials
# </div>
#
# In order to be able to access tweets from our application, we need a Tweeter account, consumer keys and access tokens.
#
# To generates these, go to https://apps.twitter.com
# and **Create a New App**. Fill in the form and agree with the terms.
#
# Once that's done, select your app and the tab **Keys and Access Tokens**
#
# <img src="img/twitter.png" style="width:550px;">

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">
#     3.2. Accessing Twitter
# </div>

# %%
import tweepy
from tweepy import OAuthHandler
 
consumer_key    = 'PLACE_YOUR_KEYS'
consumer_secret = 'PLACE_YOUR_KEYS'
access_token    = 'PLACE_YOUR_KEYS'
access_secret   = 'PLACE_YOUR_KEYS'
 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)

# %%
for tweet in tweepy.Cursor(api.home_timeline).items(2):
    # Process a single tweet

    print(tweet._json.keys())
    print()
    print(tweet._json["id"])
    print(tweet._json["text"])
    print(tweet._json["source"])
    print(tweet._json["lang"])
    print(tweet._json["retweeted"])    
    print(tweet._json["retweet_count"])
    print(tweet._json["favorite_count"])
    print()

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">
#     3.3. Saving Tweets to REDIS
# </div>

# %%
# Lets save tweets

howManyTweets = 20

for tweet in tweepy.Cursor(api.home_timeline).items(howManyTweets):
    # Process a single tweet
    
    ##Formatting the tweet 
    redisTweet = {
                  "text"           :tweet._json["text"].encode('utf-8'), 
                  "source"         :tweet._json["source"].encode('utf-8'), 
                  "lang"           :tweet._json["lang"].encode('utf-8'), 
                  "source"         :tweet._json["source"].encode('utf-8'), 
                  "retweet_count"  :tweet._json["retweet_count"], 
                  "favorite_count" :tweet._json["favorite_count"]
                 }

    ## Saving the tweet as HASH
    myRedis.hmset(tweet._json["id"], redisTweet)
    #display(tweet._json["id"])
    
    ## Adding the Tweet id to the list of tweets
    myRedis.rpush("tweets",str(tweet._json["id"]))
       
print("Done!")

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">
#     3.4. Retrieving Tweets from REDIS
# </div>

# %%
for id in myRedis.lrange("tweets",0,99):
    print()
    print("Displaying Tweet with ID:",id)
    print("Text:",myRedis.hmget(id,"text"))
    print("ALL DATA:",myRedis.hgetall(id))
    print("========================================================================")

# %% [markdown]
# <div style="font-size:30px;color:#3665af;background-color:#E9E9F5;padding:10px;">
#     4. Load Database From CSV
# </div>
#
# Unzip "CITES Wildlife Trade Database.zip" to get "comptab_2018-01-29 16_00_comma_separated.csv"
# ### Question 11:
# Load this csv file into REDIS and compute the number of animals per Order for each importer. Your output should be similar to this:
# <br>
#
# US . Carnivora . XXX
# <br>
# US . Falconiformes . XXX
# <br>
# US . Artiodactyla . XXX
# <br>
# ...
# <br>
# AD . Acipenseriformes . XXX
# <br>
# AD . Falconiformes . XXX
# <br>
# AD . Carnivora . XXX
# <br>
# ...
#
# Measure the running time, and present the average running time for the load and the processing operations.
#
# **Please also explain your code**
# <br>
# Hint: You can download CITES Wildlife Trade Database.zip, unzip it and open comptab_2018-01-29 16_00_comma_separated.csv to see the data

# %% [markdown]
# <span style="color:RED">PLACE YOUR ANSWERS/CODE IN CELLS BELOW</span>

# %%
import redis
import pandas as pd
import time


REDIS_SERVER = '34.30.22.117'
REDIS_PORT   = 6379
myRedis = redis.StrictRedis(host=REDIS_SERVER, port=REDIS_PORT, db=0)

display(myRedis.flushdb())
display(myRedis.flushall())

df = pd.read_csv('./comptab_2018-01-29 16_00_comma_separated.csv', usecols=['Importer', 'Order', 'Importer reported quantity', 'Exporter reported quantity'])

df = df.reset_index()

starttime1 = time.time()

for index, row in df.head(len(df)-1).iterrows():
    row_dict = row.to_dict()
    myRedis.hmset(str(index), row_dict)
    myRedis.rpush("values",str(index))

endtime1 = time.time()
LoadTime = endtime1 - starttime1
print("Load time into redis - ", LoadTime )
data = {}

starttime2 = time.time()

for key in myRedis.lrange('values',0,-1):
    
    values = myRedis.hmget(key,['Order', 'Importer', 'Importer reported quantity', 'Exporter reported quantity'])
    print(values)
    importerOrder = str(values[1].decode("utf-8")) +"."+ str(values[0].decode("utf-8"))
    
    num = 0
    
    if(not values[2].decode("utf-8") == 'nan'):
        num += float(values[2].decode("utf-8"))
    if(not values[3].decode("utf-8") == 'nan'):
        num += float(values[3].decode("utf-8"))
    
    if(importerOrder in list(data.keys())):
        data[importerOrder] += num
    else:
        data[importerOrder] = num

endtime2 = time.time()

processingTime = endtime2 - starttime2
print('##################')
print("Processing Time - ", processingTime)

for key,value in data.items():
    print(key + "."+  str(value))
# Out:
# True
# True
# /tmp/ipykernel_46/2036792078.py:21: DeprecationWarning: Redis.hmset() is deprecated. Use Redis.hset() instead.
#   myRedis.hmset(str(index), row_dict)
# Load time into redis -  1662.7342710494995
# [b'Caryophyllales', b'JP', b'15.0', b'nan']
# [b'Caryophyllales', b'JP', b'245.0', b'nan']
# [b'Caryophyllales', b'CH', b'nan', b'20.0']
# [b'Caryophyllales', b'DE', b'50.0', b'nan']
# [b'Caryophyllales', b'DE', b'100.0', b'nan']
# [b'Caryophyllales', b'JP', b'nan', b'1200.0']
# [b'Caryophyllales', b'CH', b'nan', b'30.0']
# [b'Caryophyllales', b'AL', b'nan', b'228.0']
# [b'Caryophyllales', b'BA', b'nan', b'86.0']
# [b'Caryophyllales', b'CH', b'nan', b'93.0']
# [b'Caryophyllales', b'CH', b'nan', b'10.0']
# [b'Caryophyllales', b'HK', b'413.0', b'nan']
# [b'Caryophyllales', b'JP', b'3.0', b'nan']
# [b'Caryophyllales', b'JP', b'1.0', b'nan']
# [b'Caryophyllales', b'KR', b'nan', b'2000.0']
# [b'Caryophyllales', b'KW', b'62.0', b'nan']
# [b'Caryophyllales', b'MD', b'nan', b'4.0']
# ...

# %% [raw]
# From the above program we are connecting to redis locally using ip address. Then the the four columns data is extracted from the excel that is Importer, Order, importer reported quantity and exporter reported quantity  using pandas into a dataframe and each row in the datafrmae is converted into dictonary and then added to redis cache using hmset & rpush function.
# The values which are present in the redis cacahe are obtained and stored in array, each elemnet in array conatins 4 elemsnts values, the Importer reported quantity and exporter reported quantities are added again those values are added for same Impoter and order in a dictonary called data having Importer and order key name(Importer.order format) . The final values for each importer and order and sum value of data are stored in dictonary which printed at the end.
#
# The output of the above program
#
# The time taken to load information into redis-  1662.7342710494995
#
# Processing Time of information retrival from redis -  616.4421257972717
#
# JP.Caryophyllales.2338783.0
# CH.Caryophyllales.551767.356
# DE.Caryophyllales.43100.1
# AL.Caryophyllales.9082.0
# BA.Caryophyllales.36741.0
# HK.Caryophyllales.36508.08540126
# KR.Caryophyllales.712364.4062
# KW.Caryophyllales.24556.0642
# MD.Caryophyllales.27128.0
# MQ.Caryophyllales.4386.0
# RE.Caryophyllales.16343.0
# IT.Caryophyllales.1117652.0
# QA.Caryophyllales.23627.0
# TH.Caryophyllales.108783.000288
# US.Caryophyllales.1031095.7694999999
# KZ.Caryophyllales.33534.0
# NO.Caryophyllales.237058.0
# AE.Caryophyllales.106164.0
# FO.Caryophyllales.966.0
# GF.Caryophyllales.631.0
# IS.Caryophyllales.60.0
# ZA.Carcharhiniformes.9.0
# MY.Testudines.4690.0
# AU.Scleractinia.777.7
# DE.Scleractinia.456809.39
# AE.Scleractinia.17120.0
# AR.Scleractinia.2017.0
# AT.Scleractinia.25661.0
# BE.Scleractinia.20946.107
# BR.Scleractinia.23015.9
# CA.Scleractinia.75164.4
# CH.Scleractinia.42723.0
# CL.Scleractinia.2774.0
# CN.Scleractinia.106063.6
# CR.Scleractinia.2179.0
# CZ.Scleractinia.9761.0
# DK.Scleractinia.55701.0
# DO.Scleractinia.88.0
# ES.Scleractinia.27433.0
# FR.Scleractinia.321858.0
# GB.Scleractinia.313178.0
# GG.Scleractinia.150.0
# GT.Scleractinia.606.0
# HK.Scleractinia.78238.0
# IE.Scleractinia.5083.0
# IL.Scleractinia.27160.0
# IN.Scleractinia.1859.0
# IR.Scleractinia.16246.0
# IT.Scleractinia.146222.0
# JO.Scleractinia.2666.0
# JP.Scleractinia.226063.0
# KR.Scleractinia.44901.0
# KW.Scleractinia.14180.0
# LA.Scleractinia.999.0
# LB.Scleractinia.1906.0
# MX.Scleractinia.19488.0
# MY.Scleractinia.8734.0
# NL.Scleractinia.196530.5
# NO.Scleractinia.9274.0
# NZ.Scleractinia.40501.212
# PE.Scleractinia.2108.0
# PK.Scleractinia.1541.0
# PL.Scleractinia.75577.0
# QA.Scleractinia.2474.0
# RU.Scleractinia.33692.0
# SE.Scleractinia.14708.0
# SG.Scleractinia.35317.0
# SM.Scleractinia.28100.5
# TR.Scleractinia.33122.0
# TT.Scleractinia.302.0
# TW.Scleractinia.27040.0
# UA.Scleractinia.3006.0
# US.Scleractinia.2218430.8000000003
# ZA.Scleractinia.18739.0
# MC.Scleractinia.85.0
# BG.Scleractinia.1842.0
# EG.Scleractinia.402.0
# GR.Scleractinia.4732.0
# MA.Scleractinia.1879.0
# MO.Scleractinia.1146.0
# PT.Scleractinia.905.0
# RO.Scleractinia.2157.0
# SA.Scleractinia.867.0
# TH.Scleractinia.2005.0
# BD.Scleractinia.508.0
# CY.Scleractinia.2251.0
# DZ.Scleractinia.2032.0
# IS.Scleractinia.53.0
# JE.Scleractinia.40.0
# RS.Scleractinia.640.0
# OM.Scleractinia.199.0
# AM.Scleractinia.681.0
# ID.Primates.36.0
# JE.Primates.2.0
# TH.Primates.1990.6000000000001
# AU.Primates.13525.1
# CA.Primates.169750.33000000002
# CH.Primates.60403.99598999999
# CN.Primates.63678.530000000006
# DE.Primates.208534.61000000002
# FR.Primates.103306.69959300001
# GB.Primates.44723.4
# GI.Primates.1.0
# IT.Primates.325997.289
# MY.Primates.91.0
# NZ.Primates.2203.0
# SG.Primates.5616.118
# TR.Primates.7276.0
# US.Primates.595665.317
# ZA.Primates.1010.0
# CZ.Primates.117.0
# TW.Primates.26127.0
# UA.Primates.61.0
# NL.Primates.9954.381300000001
# RU.Primates.3032.0
# ES.Primates.4451.219999999999
# AE.Primates.7123.0
# HU.Primates.765.0
# KP.Primates.45.0
# SE.Primates.2223.01
# LT.Primates.4.0
# LV.Primates.7.0
# OM.Primates.4448.0
# KW.Cyatheales.12.5
# LB.Cyatheales.126.09
# ME.Cyatheales.7.1
# NO.Cyatheales.37.0
# PH.Cyatheales.24.1
# QA.Cyatheales.15.19
# SG.Cyatheales.806.9653
# UA.Cyatheales.89.723
# VN.Cyatheales.7.64
# BS.Cycadales.102.0
# CA.Cycadales.28807.0
# JP.Cycadales.29761.0
# KN.Cycadales.76.0
# KY.Cycadales.50.0
# PA.Cycadales.1084.0
# US.Cycadales.1756386.0
# AE.Cycadales.66010.0
# AF.Cycadales.1500.0
# AM.Cycadales.45.0
# AO.Cycadales.21.0
# AU.Cycadales.3500.0
# AZ.Cycadales.25.0
# BA.Cycadales.247.0
# BH.Cycadales.726.0
# BY.Cycadales.574.0
# CH.Cycadales.2041.0
# CN.Cycadales.1170.0
# CV.Cycadales.24.0
# CY.Cycadales.528.0
# DE.Cycadales.25391.0
# DZ.Cycadales.665.0
# ES.Cycadales.94672.0
# FR.Cycadales.1587.0
# GE.Cycadales.411.0
# GF.Cycadales.9.0
# GP.Cycadales.842.0
# HK.Cycadales.20.0
# IQ.Cycadales.2947.0
# IT.Cycadales.15445.0
# JO.Cycadales.12025.0
# KW.Cycadales.4405.8
# KZ.Cycadales.1013.0
# LB.Cycadales.1820.0
# MA.Cycadales.3239.0
# MD.Cycadales.268.0
# ME.Cycadales.787.0
# MG.Cycadales.36.0
# MK.Cycadales.676.0
# MQ.Cycadales.214.0
# MV.Cycadales.22.0
# nan.Cycadales.2.0
# NL.Cycadales.2139111.624
# NO.Cycadales.301.0
# OM.Cycadales.6520.0
# PT.Cycadales.5748.0
# QA.Cycadales.18260.0
# RE.Cycadales.171.0
# RS.Cycadales.327.0
# RU.Cycadales.315.0
# SA.Cycadales.5.0
# SG.Cycadales.85.0
# SR.Cycadales.15.0
# TM.Cycadales.50.0
# TN.Cycadales.8976.0
# TR.Cycadales.6422.0
# UA.Cycadales.3423.0
# XX.Cycadales.239.0
# US.Cetacea.4573.4
# CA.Cetacea.1186.0
# GB.Cetacea.363.0
# BB.Cetacea.134.0
# RU.Cetacea.57.0
# DE.Cetacea.54.0
# DK.Cetacea.2329.35
# IE.Cetacea.800.0
# NZ.Cetacea.400.0
# AT.Cetacea.16.0
# AU.Cetacea.12.0
# BE.Cetacea.8.0
# CN.Cetacea.425.0
# JP.Cetacea.648.0
# SK.Cetacea.1.0
# HK.Cetacea.54.0
# BH.Cetacea.2.0
# BS.Cetacea.6.0
# DO.Cetacea.7.0
# EG.Cetacea.6.0
# FR.Cetacea.19.003999999999998
# KN.Cetacea.200.0
# KR.Cetacea.70.0
# MN.Cetacea.3.0
# MX.Cetacea.80.0
# SA.Cetacea.10.0
# TR.Cetacea.13.0
# VE.Cetacea.8.0
# VG.Cetacea.11.0
# VN.Cetacea.5.0
# XX.Cetacea.10.0
# JP.Anura.10202.1001
# KR.Anura.922.0
# PH.Anura.147.0
# TW.Anura.610.0
# US.Anura.53262.22
# DE.Anura.976.0
# NL.Anura.1424.0
# CA.Anura.1259.0
# DK.Anura.1049.0
# ES.Anura.5761.0
# FR.Anura.389.0
# SG.Anura.45.0
# TR.Anura.240.0
# CH.Anura.83.01
# CN.Anura.2.0
# BE.Anura.827.0
# GB.Anura.2500.0
# IS.Anura.18.0
# MX.Anura.33.0
# SK.Anura.200.0
# TH.Anura.135.0
# XX.Anura.600.0
# IL.Anura.0.1
# JE.Anura.16.0
# KP.Scleractinia.197.0
# DE.Dicksoniales.2.0
# US.Dicksoniales.2645.0
# NZ.Dicksoniales.0.648
# JP.Liliales.114778.3836
# AE.Nepenthales.896.0
# AT.Nepenthales.303.0
# AU.Nepenthales.32467.0
# BE.Nepenthales.930.0
# BN.Nepenthales.400.0
# CA.Nepenthales.157114.0
# CH.Nepenthales.23257.0
# CN.Nepenthales.75.0
# CZ.Nepenthales.158.0
# DK.Nepenthales.1468.0
# DO.Nepenthales.757.0
# FI.Nepenthales.75.0
# FR.Nepenthales.1223.68
# GB.Nepenthales.18450.0
# GR.Nepenthales.9954.425
# HK.Nepenthales.8137.0
# HU.Nepenthales.90.0
# IN.Nepenthales.1000.0
# IT.Nepenthales.85.0
# JP.Nepenthales.150023.5
# KR.Nepenthales.56204.0
# MX.Nepenthales.43468.0
# MY.Nepenthales.37546.0
# NL.Nepenthales.33.0
# NZ.Nepenthales.1045.0
# PE.Nepenthales.86.0
# PH.Nepenthales.513.0
# PT.Nepenthales.30.0
# RO.Nepenthales.465.0
# SE.Nepenthales.170.0
# SG.Nepenthales.1386.0
# SK.Nepenthales.30.0
# TH.Nepenthales.1410.0
# TW.Nepenthales.2524.0
# US.Nepenthales.760056.0
# IQ.Nepenthales.676.0
# NO.Nepenthales.7588.0
# CH.Ebenales.71.0
# GB.Ebenales.1.0
# SN.Ebenales.1.0
# US.Ebenales.2.0
# NL.Ebenales.1.0
# CL.Serpentes.910.0
# IL.Serpentes.6758.00001
# IN.Serpentes.7046.0
# MA.Serpentes.827.0
# NO.Serpentes.4205.9
# PE.Serpentes.1486.0
# PT.Serpentes.4918.0
# SK.Serpentes.393.0
# ZA.Serpentes.5314.0
# AD.Proboscidea.956.0
# AE.Proboscidea.3.0
# AM.Proboscidea.12.0
# AR.Proboscidea.501.0
# AT.Proboscidea.375.0
# AU.Proboscidea.1.0
# AZ.Proboscidea.12.0
# BE.Proboscidea.47.0
# BG.Proboscidea.28.0
# BH.Proboscidea.2.0
# BN.Proboscidea.4.0
# BR.Proboscidea.31.0
# CA.Proboscidea.230.0
# CH.Proboscidea.120.0
# CL.Proboscidea.9.0
# CN.Proboscidea.1615.0
# CZ.Proboscidea.29.0
# DE.Proboscidea.832.0
# DK.Proboscidea.10.0
# EE.Proboscidea.1.0
# ES.Proboscidea.670.0
# FR.Proboscidea.1380.96
# GB.Proboscidea.64.0
# GR.Proboscidea.1.0
# GY.Proboscidea.3.0
# HK.Proboscidea.63.0
# HU.Proboscidea.266.0
# IL.Proboscidea.12.0
# IR.Proboscidea.26.044999999999998
# IT.Proboscidea.1091.0
# JP.Proboscidea.1222.67
# KP.Proboscidea.1.0
# KR.Proboscidea.74.0
# KW.Proboscidea.18.560000000000002
# LB.Proboscidea.8.0
# LT.Proboscidea.84.0
# MC.Proboscidea.2012.0
# MG.Proboscidea.8.0
# MO.Proboscidea.21.0
# MX.Proboscidea.879.0
# MY.Proboscidea.1.0
# nan.Proboscidea.202.225
# NG.Proboscidea.3.0
# NL.Proboscidea.54.0
# NO.Proboscidea.35.0
# NZ.Proboscidea.8.0
# PE.Proboscidea.93.4
# PK.Proboscidea.5.16
# PL.Proboscidea.81.0
# PT.Proboscidea.30.0
# QA.Proboscidea.4.0
# RO.Proboscidea.6.0
# RU.Proboscidea.463.89000000000004
# SE.Proboscidea.61.0
# SG.Proboscidea.9.0
# SK.Proboscidea.3.0
# TR.Proboscidea.22.0
# TZ.Proboscidea.3.0
# UA.Proboscidea.137.0
# US.Proboscidea.7800.0
# UZ.Proboscidea.24.0
# XX.Proboscidea.23.0
# ZA.Proboscidea.1072.8
# ZM.Proboscidea.108.0
# SG.Passeriformes.37.0
# AR.Passeriformes.7.0
# CN.Passeriformes.50.0
# CH.Testudines.25.0
# CN.Testudines.131733.0
# HK.Testudines.1478045.0
# ID.Testudines.11610.0
# TW.Testudines.10612.0
# ES.Testudines.27709.0
# IT.Testudines.243806.0
# KR.Testudines.30554.0
# MO.Testudines.27343.0
# TR.Perissodactyla.8.0
# KP.Perissodactyla.2.0
# UA.Perissodactyla.13.0
# JP.Perissodactyla.8.0
# AR.Perissodactyla.17.0
# AT.Perissodactyla.257.0
# AU.Perissodactyla.33.0
# BA.Perissodactyla.1.0
# BE.Perissodactyla.69.0
# BG.Perissodactyla.26.0
# BR.Perissodactyla.12.0
# CA.Perissodactyla.53.0
# CH.Perissodactyla.44.0
# CM.Perissodactyla.1.0
# CN.Perissodactyla.194.0
# CZ.Perissodactyla.44.0
# DE.Perissodactyla.2071.0
# DK.Perissodactyla.311.0
# EE.Perissodactyla.8.0
# ES.Perissodactyla.120.275
# FI.Perissodactyla.27.0
# FR.Perissodactyla.130.0
# GB.Perissodactyla.70.0
# HK.Perissodactyla.25.0
# HU.Perissodactyla.117.0
# IE.Perissodactyla.1.0
# IS.Perissodactyla.5.0
# IT.Perissodactyla.31.0
# KE.Perissodactyla.2.0
# LT.Perissodactyla.2.0
# LU.Perissodactyla.1.0
# MX.Perissodactyla.25.0
# nan.Perissodactyla.47.0
# NL.Perissodactyla.19.0
# NO.Perissodactyla.64.0
# NZ.Perissodactyla.18.0
# PL.Perissodactyla.20.0
# PT.Perissodactyla.25.0
# RO.Perissodactyla.7.0
# RU.Perissodactyla.36.0
# SA.Perissodactyla.1.0
# SE.Perissodactyla.98.0
# SI.Perissodactyla.4.0
# SK.Perissodactyla.53.0
# SN.Perissodactyla.1.0
# TH.Perissodactyla.4.0
# US.Perissodactyla.1270.0
# UY.Perissodactyla.1.0
# VE.Perissodactyla.1.0
# VN.Perissodactyla.4.0
# ZA.Perissodactyla.275.0
# ZW.Perissodactyla.1.0
# AE.Passeriformes.138.0
# AW.Passeriformes.43.0
# CA.Passeriformes.208.0
# CW.Passeriformes.50.0
# GT.Passeriformes.2800.0
# IL.Passeriformes.227.0
# MV.Euphorbiales.62.0
# CY.Euphorbiales.4080.0
# SD.Euphorbiales.13.0
# BQ.Euphorbiales.192.0
# nan.Euphorbiales.14.0
# AO.Euphorbiales.28.0
# CA.Falconiformes.66.0
# CH.Falconiformes.24.0
# DE.Falconiformes.30.0
# GB.Falconiformes.46.0
# AE.Falconiformes.1288.0
# AT.Falconiformes.19.0
# EG.Falconiformes.4.0
# JP.Falconiformes.222.0
# MA.Falconiformes.2.0
# SD.Falconiformes.6.0
# AM.Falconiformes.2.0
# AZ.Falconiformes.1.0
# BH.Falconiformes.64.0
# BR.Falconiformes.4.0
# CN.Falconiformes.12301.0
# CZ.Falconiformes.5.0
# DZ.Falconiformes.4.0
# ES.Falconiformes.48.0
# FR.Falconiformes.1.0
# GE.Falconiformes.1.0
# IQ.Falconiformes.1.0
# IR.Falconiformes.17.0
# KW.Falconiformes.15.0
# KZ.Falconiformes.46.0
# MX.Falconiformes.2.0
# PK.Falconiformes.1.0
# QA.Falconiformes.801.0
# RS.Falconiformes.5.0
# SA.Falconiformes.15.0
# SK.Falconiformes.2.0
# TN.Falconiformes.21.0
# UZ.Falconiformes.670.0
# XV.Falconiformes.9.0
# LI.Falconiformes.2.0
# NP.Falconiformes.14.0
# TH.Falconiformes.5.0
# KR.Falconiformes.1.0
# US.Falconiformes.70.0
# BD.Falconiformes.6.0
# NZ.Falconiformes.1.0
# SN.Scleractinia.1.0
# AR.Carnivora.14.0
# BG.Carnivora.10.0
# DZ.Carnivora.6.0
# IE.Carnivora.8.0
# IN.Carnivora.7.0
# JO.Carnivora.6.0
# MG.Carnivora.10.0
# NC.Carnivora.2.0
# PT.Carnivora.43.0
# RO.Carnivora.29.0
# SN.Carnivora.6.0
# UG.Carnivora.2.0
# ZA.Carnivora.20245.0
# CO.Carnivora.12.7
# JE.Carnivora.2.0
# SA.Carnivora.13.0
# MK.Carnivora.187.0
# NP.Carnivora.16.0
# BY.Carnivora.15.0
# GR.Carnivora.18835.305
# BM.Carnivora.2.0
# IM.Carnivora.2.0
# TN.Carnivora.13.0
# UZ.Carnivora.7.0
# AM.Carnivora.1.0
# SM.Carnivora.244.0
# BH.Carnivora.4.0
# BR.Carnivora.1521.671
# MA.Carnivora.9.0
# MN.Carnivora.2.0
# PE.Carnivora.2.0
# TZ.Carnivora.1.0
# VN.Carnivora.210.0
# PA.Carnivora.1.0
# PK.Carnivora.2.0
# UG.Scleractinia.4.0
# JE.Sauria.2.0
# AR.Testudines.25.0
# PH.Testudines.1420.0
# RU.Testudines.223.0
# NL.Testudines.22128.0
# AT.Testudines.3.0
# GB.Testudines.41498.0
# FR.Gruiformes.8.0
# GB.Gruiformes.5.0
# QA.Gruiformes.126.0
# SG.Gruiformes.28.0
# CD.Gruiformes.2.0
# KP.Gruiformes.5.0
# KR.Gruiformes.4.0
# NZ.Gruiformes.1.0
# TN.Gruiformes.4.0
# ZA.Gruiformes.3526.0
# AE.Gruiformes.36.0
# AO.Gruiformes.10.0
# CN.Gruiformes.30.0
# MY.Gruiformes.2.0
# US.Gruiformes.3828.17
# BD.Gruiformes.12.0
# GT.Gruiformes.2.0
# NP.Gruiformes.10.0
# RU.Gruiformes.5.0
# SN.Gruiformes.5.0
# TW.Gruiformes.6.0
# UA.Gruiformes.1.0
# CA.Gruiformes.49.5
# DE.Gruiformes.300.0
# ID.Gruiformes.8.0
# HU.Gruiformes.1.0
# SN.Helioporacea.1.0
# US.Helioporacea.11337.0
# AE.Helioporacea.60.0
# AT.Helioporacea.71.0
# BG.Helioporacea.40.0
# BR.Helioporacea.20.0
# CA.Helioporacea.135.0
# CH.Helioporacea.76.0
# CN.Helioporacea.52.0
# CY.Helioporacea.1.0
# DE.Helioporacea.708.0
# DK.Helioporacea.8.0
# ES.Helioporacea.21.0
# FR.Helioporacea.45.0
# GB.Helioporacea.107.0
# GR.Helioporacea.20.0
# HK.Helioporacea.160.0
# IL.Helioporacea.136.0
# IN.Helioporacea.2.0
# IR.Helioporacea.14.0
# IT.Helioporacea.1.0
# JO.Helioporacea.12.0
# JP.Helioporacea.296.0
# KR.Helioporacea.99.0
# KW.Helioporacea.41.0
# LB.Helioporacea.7.0
# MA.Helioporacea.26.0
# MU.Helioporacea.1.0
# NL.Helioporacea.2.0
# PE.Helioporacea.19.0
# PK.Helioporacea.4.0
# PL.Helioporacea.66.0
# RU.Helioporacea.57.0
# SA.Helioporacea.2.0
# SE.Helioporacea.15.0
# TR.Helioporacea.68.0
# TW.Helioporacea.29.0
# UA.Helioporacea.9.0
# ZA.Helioporacea.58.0
# CR.Sauria.1.0
# TR.Sauria.7870.5
# KP.Sauria.245.0
# ZA.Sauria.909.0
# ES.Artiodactyla.324.21000000000004
# AT.Artiodactyla.121.0
# BE.Artiodactyla.151.0
# BG.Artiodactyla.1.0
# CZ.Artiodactyla.5.0
# DK.Artiodactyla.29.0
# FI.Artiodactyla.4.0
# GT.Artiodactyla.2.0
# HU.Artiodactyla.4312.0
# IS.Artiodactyla.12.0
# KP.Artiodactyla.1.0
# NO.Artiodactyla.527.0
# NZ.Artiodactyla.10.0
# PL.Artiodactyla.116.0
# RO.Artiodactyla.11.0
# SE.Artiodactyla.51.0
# SK.Artiodactyla.2.0
# YU.Artiodactyla.1.0
# ZM.Artiodactyla.3.0
# ZW.Artiodactyla.46.0
# CA.Arhynchobdellida.6000.0
# CH.Arhynchobdellida.76180.3
# EE.Arhynchobdellida.2000.0
# FR.Arhynchobdellida.120480.0
# KR.Arhynchobdellida.7000.0
# LV.Arhynchobdellida.44974.0
# PL.Arhynchobdellida.11.0
# US.Arhynchobdellida.191917.6
# DE.Arhynchobdellida.830.0
# GB.Arhynchobdellida.54.0
# IL.Arhynchobdellida.17000.0
# JP.Arhynchobdellida.4400.0
# MY.Arhynchobdellida.9.75
# NO.Arhynchobdellida.1137.0
# UA.Arhynchobdellida.25.0
# XX.Arhynchobdellida.14.45
# AE.Anura.36.0
# CZ.Anura.570.0
# HK.Anura.3750.0
# MY.Anura.23.0
# SV.Anura.200.0
# BR.Sauria.179.32999999999998
# GR.Sauria.3000.0
# IL.Sauria.1174.0
# IT.Sauria.268993.5
# CL.Psittaciformes.564.0
# SR.Psittaciformes.20.0
# CH.Psittaciformes.95.024
# KR.Psittaciformes.2332.0
# LB.Psittaciformes.3674.0
# AW.Psittaciformes.88.0
# BH.Psittaciformes.23718.0
# BN.Psittaciformes.82.0
# BS.Psittaciformes.24.0
# BZ.Psittaciformes.2.0
# GT.Psittaciformes.10455.0
# MX.Psittaciformes.21352.0
# GT.Serpentes.44.0
# DE.Pholidota.44.0
# SN.Pholidota.1.0
# US.Pholidota.615.0
# CN.Pholidota.8500.0
# FR.Pholidota.82.0
# HK.Pholidota.6528.0
# LA.Pholidota.99.0
# KP.Pholidota.1.0
# SG.Pholidota.1.0
# ID.Anura.65.0
# IT.Anura.50.0
# HU.Anura.82.0
# NL.Sapindales.57254.0
# CH.Sapindales.15640.439999999999
# GB.Sapindales.716943.3300000001
# JP.Sapindales.1016724.2342000001
# US.Sapindales.2313067.3999999994
# AU.Sapindales.406.03999999999996
# CA.Sapindales.1721446.0
# CN.Sapindales.5333006.041999999
# DE.Sapindales.83611.524
# DO.Sapindales.3928128.275
# GL.Sapindales.0.032
# HK.Sapindales.1540.22
# IL.Sapindales.75.74
# KR.Sapindales.59110.97
# LB.Sapindales.41293.61
# MX.Sapindales.3686861.0
# NZ.Sapindales.0.04
# RU.Sapindales.21.808
# TH.Sapindales.1.6300000000000001
# AE.Milleporina.16.0
# AM.Milleporina.5.0
# AR.Milleporina.10.0
# AT.Milleporina.15.0
# BE.Milleporina.17.0
# BG.Milleporina.20.0
# BR.Milleporina.10.0
# CA.Milleporina.148.0
# CH.Milleporina.27.0
# CN.Milleporina.60.0
# DE.Milleporina.349.0
# DK.Milleporina.2.0
# DZ.Milleporina.2.0
# ES.Milleporina.18.0
# FR.Milleporina.1210.0
# GB.Milleporina.163.0
# GR.Milleporina.1.0
# GU.Milleporina.220.0
# HK.Milleporina.145.0
# IE.Milleporina.10.0
# IL.Milleporina.106.0
# IR.Milleporina.30.0
# IT.Milleporina.14.0
# JO.Milleporina.2.0
# JP.Milleporina.429.0
# KP.Milleporina.11.0
# KR.Milleporina.102.0
# KW.Milleporina.23.0
# MX.Milleporina.25.0
# MY.Milleporina.8.0
# NL.Milleporina.5.0
# NO.Milleporina.5.0
# NZ.Milleporina.518.0
# PE.Milleporina.18.0
# PK.Milleporina.12.0
# PL.Milleporina.34.0
# RU.Milleporina.63.0
# SE.Milleporina.6.0
# TR.Milleporina.8.0
# TW.Milleporina.36.0
# UA.Milleporina.3.0
# US.Milleporina.719.0
# ZA.Milleporina.86.0
# XX.Milleporina.6.0
# MC.Milleporina.10.0
# CH.Cetacea.3.0
# FO.Cetacea.1.0
# ID.Cetacea.1.0
# IN.Cetacea.1.0
# IT.Cetacea.11.0
# MC.Cetacea.2.0
# SE.Cetacea.1.0
# CZ.Cetacea.1.0
# GL.Cetacea.3.0
# IS.Cetacea.1.0
# MO.Cetacea.1.0
# NO.Cetacea.1.0
# SG.Cetacea.1.0
# ID.Artiodactyla.17340.0
# CL.Passeriformes.10.0
# OM.Passeriformes.159.0
# SR.Passeriformes.2.0
# CL.Orchidales.45547.0
# MC.Orchidales.9.0
# MX.Orchidales.8065.0
# BL.Orchidales.19.0
# LK.Orchidales.12680.0
# MO.Orchidales.17439.0
# nan.Orchidales.60.0
# PE.Orchidales.129.0
# UY.Orchidales.125.0
# VE.Orchidales.27000.0
# BG.Orchidales.3665.0
# FI.Orchidales.11284.2
# FJ.Orchidales.20.0
# GR.Orchidales.41260.0
# IE.Orchidales.20940.79
# MT.Orchidales.11.79
# RO.Orchidales.2516.7
# SI.Orchidales.14840.0
# AU.Scrophulariales.0.25
# CA.Scrophulariales.1.0
# JP.Scrophulariales.18100.1
# KR.Scrophulariales.31.0
# SG.Scrophulariales.10.0
# US.Scrophulariales.35319.256
# MM.Carnivora.5.0
# DK.Gruiformes.3.0
# ES.Gruiformes.23.0
# JP.Gruiformes.5.0
# ES.Arecales.20.0
# FR.Arecales.50.0
# MA.Arecales.500.0
# GB.Arecales.86.0
# AU.Arecales.50.0
# BS.Arecales.8.0
# CA.Arecales.427202.24
# HK.Arecales.11129.02
# NL.Arecales.1100.0
# PK.Arecales.346.0
# US.Arecales.2801.0
# BE.Falconiformes.1.0
# US.Lepidoptera.41425.0
# CH.Lepidoptera.22.0
# CN.Lepidoptera.1996.0
# DE.Lepidoptera.7820.0
# FR.Lepidoptera.1199.0
# GB.Lepidoptera.591.0
# JP.Lepidoptera.2689.0
# KR.Lepidoptera.1830.0
# MY.Lepidoptera.34.0
# NZ.Lepidoptera.8890.0
# RU.Lepidoptera.37741.0
# IT.Lepidoptera.20.0
# AU.Lepidoptera.12.0
# FI.Lepidoptera.21.0
# NL.Lepidoptera.35.0
# BE.Lepidoptera.112.0
# PL.Lepidoptera.16.0
# SG.Lepidoptera.2500.0
# ES.Lepidoptera.20.0
# AE.Lepidoptera.150.0
# CA.Lepidoptera.3020.0
# KZ.Lepidoptera.100.0
# MK.Lepidoptera.195.0
# TR.Lepidoptera.400.0
# UZ.Lepidoptera.560.0
# AU.Passeriformes.20.0
# FR.Passeriformes.3.5
# ES.Passeriformes.1.0
# NL.Passeriformes.4.0
# SE.Passeriformes.1.0
# DE.Violales.5.0
# FR.Violales.5.0
# TR.Violales.5.0
# ZA.Violales.10.0
# FR.Scrophulariales.112251.0
# US.Diprotodontia.9.0
# ES.Diprotodontia.1.0
# RU.Galliformes.8.0
# AR.Galliformes.12.0
# NO.Galliformes.190.0
# US.Galliformes.5204426.958
# KP.Galliformes.1.0
# AE.Galliformes.560.0
# AZ.Galliformes.2.0
# BD.Galliformes.50.0
# CL.Galliformes.32.0
# GH.Galliformes.10.0
# KW.Galliformes.286.0
# OM.Galliformes.50.0
# PK.Galliformes.27.0
# TR.Galliformes.4.0
# NP.Galliformes.36.0
# QA.Galliformes.623.0
# NL.Cetacea.269.0
# CN.Ciconiiformes.480.0
# FR.Ciconiiformes.28.0
# HK.Ciconiiformes.4.0
# SG.Ciconiiformes.2.0
# KP.Ciconiiformes.8.0
# US.Ciconiiformes.5.0
# AE.Ciconiiformes.176.0
# ID.Ciconiiformes.35.0
# JP.Ciconiiformes.5.0
# KR.Ciconiiformes.22.0
# NL.Ciconiiformes.12.0
# NZ.Ciconiiformes.5.0
# ET.Scleractinia.1.0
# GU.Scleractinia.444.0
# BH.Scleractinia.1.0
# BL.Scleractinia.3.0
# PY.Scleractinia.1.0
# KP.Testudines.503.0
# CH.Acipenseriformes.44.885
# DE.Acipenseriformes.214.0
# JP.Acipenseriformes.42503.280373053996
# SG.Acipenseriformes.3.0
# TW.Acipenseriformes.33000.0
# US.Primulales.196072.38789999997
# CH.Primulales.9239.52
# NL.Primulales.1865760.0
# CA.Primulales.1001.6199999999999
# FR.Primulales.1266.0
# TN.Primulales.200.0
# ES.Primulales.10010.0
# JP.Primulales.51080.0
# UZ.Primulales.165.2108
# BY.Primulales.100.07721
# KR.Primulales.100.0
# DE.Primulales.13.0
# GE.Primulales.0.0508
# KG.Primulales.0.0057
# KI.Primulales.0.0062
# KZ.Primulales.0.20873
# MN.Primulales.0.0023
# RU.Primulales.2.0194
# TM.Primulales.0.016
# UA.Primulales.0.3175
# UY.Primulales.0.0159
# BR.Psittaciformes.295.0
# PH.Psittaciformes.2409.0
# BM.Psittaciformes.32.0
# CA.Psittaciformes.397.0
# CD.Psittaciformes.52.0
# CW.Psittaciformes.2221.0
# ES.Psittaciformes.13.0
# GH.Psittaciformes.58.0
# ID.Psittaciformes.42078.0
# KP.Psittaciformes.108.0
# KZ.Psittaciformes.123.0
# MY.Psittaciformes.6141.0
# NO.Psittaciformes.858.0
# SN.Psittaciformes.146.0
# TH.Psittaciformes.5224.0
# ZA.Psittaciformes.1147.0
# ZW.Psittaciformes.3.0
# PT.Psittaciformes.77.0
# IQ.Psittaciformes.212.0
# NP.Psittaciformes.190.0
# EG.Psittaciformes.936.0
# VN.Psittaciformes.120.0
# CN.Psittaciformes.9058.0
# DE.Psittaciformes.299.0
# GB.Psittaciformes.55.0
# IN.Psittaciformes.22.0
# SE.Psittaciformes.16.0
# TN.Psittaciformes.4.0
# VE.Psittaciformes.2.0
# XX.Psittaciformes.172.0
# AM.Psittaciformes.14.0
# AT.Psittaciformes.5.0
# BB.Psittaciformes.280.0
# CY.Psittaciformes.128.0
# JM.Psittaciformes.34.0
# LY.Psittaciformes.254.0
# TT.Psittaciformes.77.0
# UZ.Psittaciformes.446.0
# VG.Psittaciformes.16.0
# UA.Psittaciformes.2980.0
# DK.Psittaciformes.12.0
# UY.Psittaciformes.2.0
# AO.Psittaciformes.16.0
# AZ.Psittaciformes.4.0
# BE.Psittaciformes.38.0
# DZ.Psittaciformes.1.0
# GE.Psittaciformes.18.0
# IT.Psittaciformes.7.0
# KE.Psittaciformes.7.0
# KG.Psittaciformes.2.0
# LK.Psittaciformes.6.0
# LT.Psittaciformes.9.0
# LV.Psittaciformes.4.0
# MA.Psittaciformes.5.0
# ME.Psittaciformes.4.0
# MU.Psittaciformes.2.0
# RU.Psittaciformes.225.0
# TZ.Psittaciformes.1.0
# CR.Psittaciformes.5.0
# HN.Psittaciformes.2.0
# TJ.Psittaciformes.7.0
# IE.Psittaciformes.4.0
# AN.Psittaciformes.23.0
# HR.Rosales.23742.64
# IN.Rosales.36924.0
# JP.Rosales.0.126
# ME.Rosales.12970.0
# MG.Rosales.176078.0
# MK.Rosales.31980.0
# NL.Rosales.17.0
# SG.Rosales.360.0
# US.Rosales.23081.199999999997
# UY.Rosales.10.0
# ZA.Rosales.20.0
# UZ.Nepenthales.24.0
# GI.Nepenthales.15.0
# MG.Nepenthales.29.0
# BB.Nepenthales.5.0
# BH.Nepenthales.24.0
# BQ.Nepenthales.9.0
# ZW.Nepenthales.24.0
# SG.Sauria.250737.5
# SK.Rodentia.6.0
# US.Scorpiones.1011.0
# HK.Scorpiones.810.0
# GB.Scrophulariales.500.0
# DE.Sphenisciformes.15.0
# GB.Sphenisciformes.50.0
# US.Sphenisciformes.36.0
# AU.Carcharhiniformes.20.0
# DE.Carcharhiniformes.167.0
# KR.Carcharhiniformes.94970.0
# CA.Carcharhiniformes.1.0
# JP.Strigiformes.2899.0
# DE.Strigiformes.9.0
# CA.Strigiformes.6.0
# KP.Strigiformes.8.0
# US.Strigiformes.303.25
# ES.Strigiformes.1735.0
# TW.Strigiformes.3.0
# AT.Strigiformes.1.0
# CH.Strigiformes.31.0
# KW.Strigiformes.23.0
# NP.Strigiformes.27.0
# NZ.Strigiformes.12.0
# AE.Strigiformes.6.0
# BE.Strigiformes.5.0
# EC.Strigiformes.2.0
# GB.Strigiformes.19.0
# HK.Strigiformes.2.0
# JE.Strigiformes.2.0
# MA.Strigiformes.1.0
# NO.Strigiformes.10.0
# TH.Strigiformes.13.0
# KR.Strigiformes.7.0
# FR.Strigiformes.11.0
# AR.Strigiformes.2.0
# BR.Strigiformes.3.0
# DK.Strigiformes.1.0
# GL.Strigiformes.1.0
# ID.Strigiformes.10.0
# MC.Strigiformes.10.0
# MX.Strigiformes.3.0
# QA.Strigiformes.12.0
# UA.Strigiformes.3.0
# RU.Strigiformes.12.0
# PT.Strigiformes.1.0
# AU.Strigiformes.16.0
# AE.Mesogastropoda.2294.7
# AW.Mesogastropoda.2607.9700000000003
# BE.Mesogastropoda.2.0
# BH.Mesogastropoda.1.0
# CA.Mesogastropoda.68494.47
# CH.Mesogastropoda.98.0
# CN.Mesogastropoda.108733.8
# CW.Mesogastropoda.40778.36
# DE.Mesogastropoda.1.0
# ES.Mesogastropoda.1.0
# FR.Mesogastropoda.403348.11
# GB.Mesogastropoda.46.0
# HK.Mesogastropoda.13365.58
# IT.Mesogastropoda.50152.0
# JP.Mesogastropoda.4770.34
# KY.Mesogastropoda.4880.97
# LC.Mesogastropoda.11.54
# NZ.Mesogastropoda.0.8
# PR.Mesogastropoda.65771.55
# QA.Mesogastropoda.28.0
# TH.Mesogastropoda.3.0
# TT.Mesogastropoda.180.0
# TW.Mesogastropoda.16.0
# US.Mesogastropoda.2860021.1007999997
# VA.Mesogastropoda.500.0
# VN.Mesogastropoda.7837.0
# XX.Mesogastropoda.112.0
# BG.Passeriformes.5.0
# CH.Passeriformes.1.0
# IR.Passeriformes.30.0
# JO.Passeriformes.93.0
# SA.Passeriformes.75.0
# VN.Passeriformes.20.0
# IT.Stylasterina.51.0
# AE.Stylasterina.5.0
# AR.Stylasterina.13.0
# AT.Stylasterina.1.0
# BR.Stylasterina.7.0
# CA.Stylasterina.109.0
# CH.Stylasterina.24.0
# CN.Stylasterina.39.0
# CY.Stylasterina.13.0
# DE.Stylasterina.277.0
# DK.Stylasterina.124.0
# ES.Stylasterina.15.0
# FR.Stylasterina.371.0
# GB.Stylasterina.82.0
# HK.Stylasterina.95.0
# IL.Stylasterina.35.0
# IR.Stylasterina.10.0
# JO.Stylasterina.7.0
# JP.Stylasterina.252.0
# KR.Stylasterina.72.0
# KW.Stylasterina.13.0
# LB.Stylasterina.16.0
# NL.Stylasterina.36.0
# NO.Stylasterina.4.0
# NZ.Stylasterina.250.0
# PE.Stylasterina.5.0
# PL.Stylasterina.5.0
# SE.Stylasterina.40.0
# SG.Stylasterina.3.0
# TR.Stylasterina.2.0
# TW.Stylasterina.10.0
# US.Stylasterina.1021.0
# ZA.Stylasterina.110.0
# MY.Stylasterina.5.0
# DK.Syngnathiformes.540.0
# US.Syngnathiformes.14642.25
# CH.Syngnathiformes.25.0
# SG.Syngnathiformes.470.0
# TH.Syngnathiformes.168.0
# HK.Syngnathiformes.203.5
# NL.Syngnathiformes.2785.0
# DE.Syngnathiformes.1130.0
# GG.Syngnathiformes.30.0
# IS.Syngnathiformes.13.0
# SM.Syngnathiformes.420.0
# TR.Syngnathiformes.121.0
# BS.Syngnathiformes.20.0
# CA.Syngnathiformes.277.42
# JP.Syngnathiformes.4549.719999999999
# MY.Syngnathiformes.110.0
# RU.Syngnathiformes.4.0
# FR.Syngnathiformes.850.0
# GB.Syngnathiformes.253.0
# PL.Syngnathiformes.200.0
# SE.Syngnathiformes.49.0
# US.Monotremata.4.0
# AE.Perissodactyla.4.0
# RS.Perissodactyla.1.0
# BE.Pinales.13.0
# CH.Pinales.89.0
# CN.Pinales.5344.0
# CZ.Pinales.27.0
# DE.Pinales.148.0
# ES.Pinales.2.0
# FR.Pinales.10.0
# GB.Pinales.1.0
# IT.Pinales.823196.0
# KR.Pinales.2.0
# SI.Pinales.77.0
# TR.Pinales.6.0
# US.Pinales.29758.025
# AE.Pinales.20.0
# IE.Pinales.8128.0
# SG.Pinales.33887.6
# TW.Pinales.6329.3
# IQ.Artiodactyla.231.0
# PT.Artiodactyla.7746.0
# SU.Artiodactyla.4.0
# TM.Artiodactyla.24.0
# AL.Artiodactyla.50.0
# AM.Artiodactyla.54.0
# BY.Artiodactyla.72.0
# JO.Artiodactyla.14.0
# MK.Artiodactyla.26.0
# UG.Artiodactyla.6.0
# AM.Sauria.188.0
# AT.Sauria.8031.0
# AU.Sauria.1210.5
# AZ.Sauria.220.5
# BH.Sauria.115.25
# CD.Sauria.14.0
# CG.Sauria.66.0
# CI.Sauria.12.0
# CM.Sauria.40.0
# CN.Sauria.176579.16999999998
# DK.Sauria.724.0
# GU.Sauria.6.0
# IN.Sauria.103.0
# IQ.Sauria.1.0
# JO.Sauria.28.0
# KZ.Sauria.32.0
# LB.Sauria.304.5
# LT.Sauria.5.0
# PE.Stolonifera.21.0
# PH.Stolonifera.1.0
# PL.Stolonifera.149.0
# PY.Stolonifera.2.0
# QA.Stolonifera.25.0
# RU.Stolonifera.70.0
# SA.Stolonifera.10.0
# SE.Stolonifera.129.0
# SG.Stolonifera.105.0
# SM.Stolonifera.109.0
# TR.Stolonifera.141.0
# TW.Stolonifera.45.0
# UA.Stolonifera.6.0
# ZA.Stolonifera.56.0
# US.Scandentia.96.6
# AL.Carnivora.1.0
# BW.Carnivora.2.0
# NG.Carnivora.3.0
# GL.Carnivora.3.0
# BD.Dipsacales.6360.0
# BE.Dipsacales.554.0
# CA.Dipsacales.2.5
# CH.Dipsacales.1105.5
# CN.Dipsacales.508.0
# ES.Dipsacales.2.0
# FR.Dipsacales.10.0
# GB.Dipsacales.25.0
# HK.Dipsacales.1.0
# IN.Dipsacales.218123.0
# KR.Dipsacales.1.0
# PK.Dipsacales.97740.0
# TW.Dipsacales.100.0
# US.Dipsacales.1548.06
# PL.Sauria.1572.0
# AN.Sauria.59.0
# AO.Sauria.7.0
# AW.Sauria.7.0
# BG.Sauria.5.0
# BL.Sauria.57.5
# BN.Sauria.2.0
# DZ.Sauria.16.0
# EG.Sauria.57.0
# ET.Sauria.3.0
# GA.Sauria.5.0
# GE.Sauria.73.0
# KH.Sauria.36.0
# KN.Sauria.24.0
# KY.Sauria.15.0
# MU.Sauria.2592.0
# NE.Sauria.2.0
# SE.Sauria.35.0
# SN.Sauria.4.0
# UG.Sauria.4.0
# AL.Sauria.9.0
# BA.Sauria.34.0
# BD.Sauria.8.0
# BJ.Sauria.1.0
# BS.Sauria.4.0
# CO.Sauria.536.0
# CW.Sauria.2.0
# DO.Sauria.34.0
# EC.Sauria.1.0
# FI.Sauria.10.0
# GH.Sauria.2.0
# GL.Sauria.1.0
# GP.Sauria.1.0
# IS.Sauria.31.0
# LA.Sauria.2.0
# LK.Sauria.13.0
# ME.Sauria.1.0
# ML.Sauria.1.0
# MR.Sauria.1.0
# PR.Sauria.5.0
# PY.Sauria.2.0
# SI.Sauria.131.0
# TG.Sauria.1.0
# VE.Sauria.3.0
# XV.Sauria.594.0
# HK.Rhamnales.161.0
# JP.Rhamnales.172.0
# TH.Rhamnales.13.0
# TW.Rhamnales.2.0
# IN.Rhamnales.4.0
# TR.Rhamnales.5.0
# ES.Rhamnales.10.0
# SG.Rhamnales.1.0
# PL.Cycadales.1.0
# AG.Cycadales.39.0
# AI.Cycadales.4.0
# SX.Cycadales.6.0
# VG.Cycadales.200.0
# KR.Cycadales.21200.0
# AE.Sapindales.16550.03
# AR.Sapindales.48376.414
# BE.Sapindales.38106.04
# BR.Sapindales.6754.0
# CL.Sapindales.52591.04
# CO.Sapindales.306.06
# EC.Sapindales.10.0
# EG.Sapindales.175.0
# ES.Sapindales.37809.861999999994
# FR.Sapindales.55660.027
# HU.Sapindales.25000.0
# ID.Sapindales.115500.0
# IN.Sapindales.57805.04
# IT.Sapindales.8167.363
# KW.Sapindales.50.0
# PE.Sapindales.58.0
# PH.Sapindales.0.015
# PK.Sapindales.380.03
# SG.Sapindales.19250.0
# TR.Sapindales.1750.05
# TW.Sapindales.102336.17
# UA.Sapindales.5.0
# VN.Sapindales.71529.0
# ZA.Sapindales.30.01
# AG.Sapindales.20.0
# KN.Sapindales.21.0
# AT.Sapindales.9596.476
# BS.Sapindales.17.0
# VC.Sapindales.9.0
# IT.Acipenseriformes.8.117
# US.Acipenseriformes.1744.5
# AU.Antipatharia.6.0
# CA.Antipatharia.18.0
# NZ.Antipatharia.1.0
# RU.Antipatharia.1.0
# SN.Antipatharia.2.0
# SN.Cetacea.2.0
# BY.nan.12.0
# KZ.nan.39.0
# US.nan.122923.0
# SG.nan.35.56
# FR.nan.49.0
# CH.nan.3.0
# DE.nan.296.0
# CA.nan.10.0
# JP.nan.62.0
# ID.nan.21.3
# IE.nan.1.0
# IT.nan.37.0
# AT.nan.1.0
# HU.Scleractinia.326.0
# KZ.Scleractinia.1000.0
# RE.Scleractinia.270.0
# UZ.Scleractinia.400.0
# AD.Anseriformes.794.0
# AE.Anseriformes.44000.0
# BR.Anseriformes.146948.0
# CA.Anseriformes.41975.0
# CH.Anseriformes.52969.0
# CL.Anseriformes.233544.0
# CO.Anseriformes.429654.0
# EC.Anseriformes.27500.0
# FR.Anseriformes.867.0
# IL.Anseriformes.36500.0
# KZ.Anseriformes.20009.0
# MA.Anseriformes.1575.0
# MX.Anseriformes.292584.0
# NL.Anseriformes.30.0
# NO.Anseriformes.24000.0
# RU.Anseriformes.2077998.0
# TN.Anseriformes.126403.0
# TW.Anseriformes.260.0
# UA.Anseriformes.88224.0
# US.Anseriformes.1369875.0
# ZA.Anseriformes.80089.0
# GR.Artiodactyla.1.0
# LV.Artiodactyla.1.0
# nan.Artiodactyla.2.0
# PA.Artiodactyla.3.0
# SN.Artiodactyla.4.0
# SV.Artiodactyla.2.0
# PH.Artiodactyla.4.0
# SE.Charadriiformes.1.0
# GB.Columbiformes.11.0
# GB.Gorgonacea.7.0
# CH.Gorgonacea.7769.72578
# CN.Gorgonacea.5859.923000000002
# FR.Gorgonacea.212.37900000000005
# HK.Gorgonacea.491.562
# US.Gorgonacea.14699.596
# AE.Gorgonacea.9.0
# AZ.Gorgonacea.2.0
# BE.Gorgonacea.0.191
# BG.Gorgonacea.8.0
# BH.Gorgonacea.48.0
# CA.Gorgonacea.14.0
# CL.Gorgonacea.14.0
# DE.Gorgonacea.1922.6924999999999
# IL.Gorgonacea.9.0
# IT.Gorgonacea.66195.98999999999
# JP.Gorgonacea.3525.2179
# KW.Gorgonacea.9.0
# KZ.Gorgonacea.9.0
# MA.Gorgonacea.0.466
# MX.Gorgonacea.6.0
# QA.Gorgonacea.165.0
# SG.Gorgonacea.4.5
# TR.Gorgonacea.6.0
# TW.Gorgonacea.12.0
# UA.Gorgonacea.2.0
# XX.Gorgonacea.74.0
# AD.Gorgonacea.0.231
# ES.Gorgonacea.3.934
# RU.Gorgonacea.1.0
# UA.Galliformes.4.0
# NP.Rodentia.7.0
# OM.Rodentia.12.0
# SA.Rodentia.1.0
# TH.Rodentia.12.0
# TR.Rodentia.11.0
