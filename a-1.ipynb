# %% [markdown]
# <hr style="border-top: 5px solid purple; margin-top: 1px; margin-bottom: 1px"></hr>

# %% [markdown]
# ***
# # <span style="font-size:35px;color:#3665af">Section 1: Word Count Example </span>
# ***
# ### Map/Reduce Classes
# We have three classes available:<br>
# - WordCount.Java &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;     *Main program* <br>
# - WordcountMapper.java &emsp;&emsp;&emsp;&emsp;                 *Implementation of the Map* <br>
# - WordCountReducer.java &emsp;&emsp;&emsp;&nbsp;                *Implementation of the Reduce* <br>
#
# <br>
# Take a look at the Main program, try to identify where the files are loaded.
# <br>
# In the same fashion, inspect the Mapper and the Reducer class to identify the emit and the collect steps on the code.
# <br>
# Now, let's run the WordCount:
#
#
# ## <span style="color:green">Transfer files: </span>
#
# <div class="alert alert-block alert-success">
#
# #### Transfer the following files to ucdenver@csci-simon-2/\<firstname_lastname> folder:
#     WordCount.Java
#     WordcountMapper.java
#     WordCountReducer.java
#     hamlet.txt
#
# </div>

# %%
##### OUTPUT Goes HERE #####
WARNING: An illegal reflective access operation has occurred
WARNING: Illegal reflective access by org.apache.hadoop.security.authentication.util.KerberosUtil (file:/home/ucdenver/hadoop-2.10.0/share/hadoop/common/lib/hadoop-auth-2.10.0.jar) to method sun.security.krb5.Config.getInstance()
WARNING: Please consider reporting this to the maintainers of org.apache.hadoop.security.authentication.util.KerberosUtil
WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
WARNING: All illegal access operations will be denied in a future release
23/02/23 15:26:41 INFO Configuration.deprecation: session.id is deprecated. Instead, use dfs.metrics.session-id
23/02/23 15:26:41 INFO jvm.JvmMetrics: Initializing JVM Metrics with processName=JobTracker, sessionId=
23/02/23 15:26:41 INFO jvm.JvmMetrics: Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
23/02/23 15:26:41 INFO mapred.FileInputFormat: Total input files to process : 1
23/02/23 15:26:41 INFO mapreduce.JobSubmitter: number of splits:1
23/02/23 15:26:41 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1148681956_0001
23/02/23 15:26:41 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
23/02/23 15:26:41 INFO mapred.LocalJobRunner: OutputCommitter set in config null
23/02/23 15:26:41 INFO mapreduce.Job: Running job: job_local1148681956_0001
23/02/23 15:26:41 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
23/02/23 15:26:41 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
23/02/23 15:26:41 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
23/02/23 15:26:41 INFO mapred.LocalJobRunner: Waiting for map tasks
23/02/23 15:26:41 INFO mapred.LocalJobRunner: Starting task: attempt_local1148681956_0001_m_000000_0
23/02/23 15:26:41 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
23/02/23 15:26:41 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
23/02/23 15:26:41 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
23/02/23 15:26:41 INFO mapred.MapTask: Processing split: hdfs://localhost:54310/user/sivapriya_akumulla/input/hamlet.txt:0+175150
23/02/23 15:26:41 INFO mapred.MapTask: numReduceTasks: 1
23/02/23 15:26:41 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
23/02/23 15:26:41 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
23/02/23 15:26:41 INFO mapred.MapTask: soft limit at 83886080
23/02/23 15:26:41 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
23/02/23 15:26:41 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
23/02/23 15:26:41 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
23/02/23 15:26:41 INFO mapred.LocalJobRunner: 
23/02/23 15:26:41 INFO mapred.MapTask: Starting flush of map output
23/02/23 15:26:41 INFO mapred.MapTask: Spilling map output
23/02/23 15:26:41 INFO mapred.MapTask: bufstart = 0; bufend = 303018; bufvoid = 104857600
23/02/23 15:26:41 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26086348(104345392); length = 128049/6553600
23/02/23 15:26:41 INFO mapred.MapTask: Finished spill 0
23/02/23 15:26:41 INFO mapred.Task: Task:attempt_local1148681956_0001_m_000000_0 is done. And is in the process of committing
23/02/23 15:26:41 INFO mapred.LocalJobRunner: hdfs://localhost:54310/user/sivapriya_akumulla/input/hamlet.txt:0+175150
23/02/23 15:26:41 INFO mapred.Task: Task 'attempt_local1148681956_0001_m_000000_0' done.
23/02/23 15:26:41 INFO mapred.Task: Final Counters for attempt_local1148681956_0001_m_000000_0: Counters: 22
	File System Counters
		FILE: Number of bytes read=3065
		FILE: Number of bytes written=852547
		FILE: Number of read operations=0
		FILE: Number of large read operations=0
		FILE: Number of write operations=0
		HDFS: Number of bytes read=175150
		HDFS: Number of bytes written=0
		HDFS: Number of read operations=5
		HDFS: Number of large read operations=0
		HDFS: Number of write operations=1
	Map-Reduce Framework
		Map input records=5567
		Map output records=32013
		Map output bytes=303018
		Map output materialized bytes=367050
		Input split bytes=115
		Combine input records=0
		Spilled Records=32013
		Failed Shuffles=0
		Merged Map outputs=0
		GC time elapsed (ms)=0
		Total committed heap usage (bytes)=526385152
	File Input Format Counters 
		Bytes Read=175150
23/02/23 15:26:41 INFO mapred.LocalJobRunner: Finishing task: attempt_local1148681956_0001_m_000000_0
23/02/23 15:26:41 INFO mapred.LocalJobRunner: map task executor complete.
23/02/23 15:26:41 INFO mapred.LocalJobRunner: Waiting for reduce tasks
23/02/23 15:26:41 INFO mapred.LocalJobRunner: Starting task: attempt_local1148681956_0001_r_000000_0
23/02/23 15:26:41 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
23/02/23 15:26:41 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
23/02/23 15:26:41 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
23/02/23 15:26:41 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@7ea6f15c
23/02/23 15:26:42 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=375809632, maxSingleShuffleLimit=93952408, mergeThreshold=248034368, ioSortFactor=10, memToMemMergeOutputsThreshold=10
23/02/23 15:26:42 INFO reduce.EventFetcher: attempt_local1148681956_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
23/02/23 15:26:42 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1148681956_0001_m_000000_0 decomp: 367046 len: 367050 to MEMORY
23/02/23 15:26:42 INFO reduce.InMemoryMapOutput: Read 367046 bytes from map-output for attempt_local1148681956_0001_m_000000_0
23/02/23 15:26:42 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 367046, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->367046
23/02/23 15:26:42 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
23/02/23 15:26:42 INFO mapred.LocalJobRunner: 1 / 1 copied.
23/02/23 15:26:42 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
23/02/23 15:26:42 INFO mapred.Merger: Merging 1 sorted segments
23/02/23 15:26:42 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 367042 bytes
23/02/23 15:26:42 INFO reduce.MergeManagerImpl: Merged 1 segments, 367046 bytes to disk to satisfy reduce memory limit
23/02/23 15:26:42 INFO reduce.MergeManagerImpl: Merging 1 files, 367050 bytes from disk
23/02/23 15:26:42 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
23/02/23 15:26:42 INFO mapred.Merger: Merging 1 sorted segments
23/02/23 15:26:42 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 367042 bytes
23/02/23 15:26:42 INFO mapred.LocalJobRunner: 1 / 1 copied.
23/02/23 15:26:42 INFO mapred.Task: Task:attempt_local1148681956_0001_r_000000_0 is done. And is in the process of committing
23/02/23 15:26:42 INFO mapred.LocalJobRunner: 1 / 1 copied.
23/02/23 15:26:42 INFO mapred.Task: Task attempt_local1148681956_0001_r_000000_0 is allowed to commit now
23/02/23 15:26:42 INFO output.FileOutputCommitter: Saved output of task 'attempt_local1148681956_0001_r_000000_0' to hdfs://localhost:54310/user/sivapriya_akumulla/output/1/_temporary/0/task_local1148681956_0001_r_000000
23/02/23 15:26:42 INFO mapred.LocalJobRunner: reduce > reduce
23/02/23 15:26:42 INFO mapred.Task: Task 'attempt_local1148681956_0001_r_000000_0' done.
23/02/23 15:26:42 INFO mapred.Task: Final Counters for attempt_local1148681956_0001_r_000000_0: Counters: 29
	File System Counters
		FILE: Number of bytes read=737197
		FILE: Number of bytes written=1219597
		FILE: Number of read operations=0
		FILE: Number of large read operations=0
		FILE: Number of write operations=0
		HDFS: Number of bytes read=175150
		HDFS: Number of bytes written=73890
		HDFS: Number of read operations=8
		HDFS: Number of large read operations=0
		HDFS: Number of write operations=3
	Map-Reduce Framework
		Combine input records=0
		Combine output records=0
		Reduce input groups=7722
		Reduce shuffle bytes=367050
		Reduce input records=32013
		Reduce output records=7722
		Spilled Records=32013
		Shuffled Maps =1
		Failed Shuffles=0
		Merged Map outputs=1
		GC time elapsed (ms)=0
		Total committed heap usage (bytes)=526385152
	Shuffle Errors
		BAD_ID=0
		CONNECTION=0
		IO_ERROR=0
		WRONG_LENGTH=0
		WRONG_MAP=0
		WRONG_REDUCE=0
	File Output Format Counters 
		Bytes Written=73890
23/02/23 15:26:42 INFO mapred.LocalJobRunner: Finishing task: attempt_local1148681956_0001_r_000000_0
23/02/23 15:26:42 INFO mapred.LocalJobRunner: reduce task executor complete.
23/02/23 15:26:42 INFO mapreduce.Job: Job job_local1148681956_0001 running in uber mode : false
23/02/23 15:26:42 INFO mapreduce.Job:  map 100% reduce 100%
23/02/23 15:26:42 INFO mapreduce.Job: Job job_local1148681956_0001 completed successfully
23/02/23 15:26:42 INFO mapreduce.Job: Counters: 35
	File System Counters
		FILE: Number of bytes read=740262
		FILE: Number of bytes written=2072144
		FILE: Number of read operations=0
		FILE: Number of large read operations=0
		FILE: Number of write operations=0
		HDFS: Number of bytes read=350300
		HDFS: Number of bytes written=73890
		HDFS: Number of read operations=13
		HDFS: Number of large read operations=0
		HDFS: Number of write operations=4
	Map-Reduce Framework
		Map input records=5567
		Map output records=32013
		Map output bytes=303018
		Map output materialized bytes=367050
		Input split bytes=115
		Combine input records=0
		Combine output records=0
		Reduce input groups=7722
		Reduce shuffle bytes=367050
		Reduce input records=32013
		Reduce output records=7722
		Spilled Records=64026
		Shuffled Maps =1
		Failed Shuffles=0
		Merged Map outputs=1
		GC time elapsed (ms)=0
		Total committed heap usage (bytes)=1052770304
	Shuffle Errors
		BAD_ID=0
		CONNECTION=0
		IO_ERROR=0
		WRONG_LENGTH=0
		WRONG_MAP=0
		WRONG_REDUCE=0
	File Input Format Counters 
		Bytes Read=175150
	File Output Format Counters 
		Bytes Written=73890

# %%
##### OUTPUT Goes HERE #####
/home/----/hadoop-2.10.0/bin/hadoop dfs -cat /user/srinath/output/1/* | head -n 10
DEPRECATED: Use of this script to execute hdfs command is deprecated.
Instead use the hdfs command for it.

WARNING: An illegal reflective access operation has occurred
WARNING: Illegal reflective access by org.apache.hadoop.security.authentication.util.KerberosUtil (file:/home/ucdenver/hadoop-2.10.0/share/hadoop/common/lib/hadoop-auth-2.10.0.jar) to method sun.security.krb5.Config.getInstance()
WARNING: Please consider reporting this to the maintainers of org.apache.hadoop.security.authentication.util.KerberosUtil
WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
WARNING: All illegal access operations will be denied in a future release
&	5
'	1
'A	1
'Adam	1
'Adieu,	1
'And	1
'Anon	1
'As	1
'As'es	1
'But	1
cat: Unable to write to output stream.

# %% [markdown]
# - Inspect the output by using the commands cat, grep, tail, head.
# - Did you notice any issues on how the counting was done? For example, look a the word "them". Was the output as you expected to be?
# - If not, how can you address the problem.
#
# ## Write your answers to the aforementioned questions in the next cell. You don't need to implement your solution.

# %% [markdown]
# By using grep specific word can be searched while searching for them it was not showing proper output instead the above snippet gives output with special characters. And the tail gives out the last n number of data.
# To address the problem related to searching the word them, tokens can be used to seperate it and get the output.

# %% [markdown]
# <hr style="border-top: 1px solid red; margin-top: 20px; margin-bottom: 1px"></hr>
#
# ## <span style="color:RED">Exercise: </span> Department monthly sales
#
# <hr style="border-top: 1px solid red; margin-top: 20px; margin-bottom: 1px"></hr>
#
# Based on the map-reduce example above, do the proper modifications to solve the following problem:
# <br>
# We are going to be using the Walmart Store Sales Forecasting competition training dataset available [here](https://www.kaggle.com/c/walmart-recruiting-store-sales-forecasting/data). Considering this dataset, you should produce a monthly summary of the sales per department. <br>
# So you output should be like:
# <pre>
# dept-year-month:$$$
# </pre>
# 1. Download the training dataset and upload it to your server for processing (using WinSCP again). Be careful with the paths you use. <br>
# 2. Using the three provided java classes as a template, create three new classes: <i>Walmart.java, WalmartMapper.java, WalmartReducer.java</i> with the proper code. <br>
# 3. Fill in the following and make sure to keep saving your work.
#
# Now, answer the following questions:

# %% [markdown]
# ### 1. Place your map function in the next cell:  <span style="font-size:12px">(Only the function) </span>

# %% [markdown]
# import java.io.IOException;
# import java.util.StringTokenizer;
#
# import org.apache.hadoop.io.*;
# import org.apache.hadoop.mapred.*;
#
#
# /***
#         Walmart Mapper class.
# ***/
# public class WalmartMapper extends MapReduceBase implements Mapper<LongWritable, Text, Text, IntWritable>
# {
#     //Hadoop supported data types
#     private                    Text info = new Text();
#
#     /*****
#         Map method that performs the tokenizer job and framing the initial key value pairs
#     ***/
#     public void map(LongWritable key,
#                     Text value,
#                     OutputCollector<Text, IntWritable> output,
#                     Reporter reporter)
#     throws IOException
#     {
#
#         /***
#             taking one line at a time and tokenizing the same
#         **/
#         String line = value.toString();
#         StringTokenizer tokenizer = new StringTokenizer(line, ",");
#
#
# 	tokenizer.nextToken(); // Ignoring the store part
# 	String department  = tokenizer.nextToken();
# 	String date = tokenizer.nextToken();
#
#         /***
#             The try statement checks for the valid integer, if not it ignores the line
#         **/
#
# 	IntWritable total;
# 	try {
# 		total = new IntWritable(Integer.parseInt(tokenizer.nextToken()));
# 	} catch(NumberFormatException e) {
# 		return;
# 	}
#
#         /***
#            Extracting the year and date from yyyy-mm-dd format
#         **/
#         StringTokenizer d_Tokenizer = new StringTokenizer(date, "-");
# 	String date_y = d_Tokenizer.nextToken();
# 	String date_m = d_Tokenizer.nextToken();
#
# 	info.set(department + "-" + date_y + "-" + date_m);
# 	output.collect(info, total);
#     }
#
# }

# %% [markdown]
# ### 2. Place your reduce function in the next cell:  <span style="font-size:12px">(Only the function) </span>

# %% [markdown]
# import java.io.IOException;
# import java.util.Iterator;
#
# import org.apache.hadoop.io.*;
# import org.apache.hadoop.mapred.*;
#
# /*****
#         Walmart Reducer class.
# *****/
# public class WordCountReducer extends MapReduceBase implements Reducer<Text, IntWritable, Text, IntWritable>
# {
#
#
#     //reduce method accepts the Key Value pairs from mappers, do the aggregation based on keys and produce the final out put
#     public void reduce( Text key,
#                         Iterator<IntWritable> values,
#                         OutputCollector<Text, IntWritable> output,
#                         Reporter reporter)
#     throws IOException
#     {
#         int sum = 0;
#
#         /******
#             iterates through all the values available with a key
#             and add them together and give the final result
#             as the key and sum of its values
#         ****/
#
#         while ( values.hasNext() ) {
#             sum += values.next().get();
#         }
#
#         output.collect(key, new IntWritable(sum));
#     }
# }

# %% [markdown]
# ### 3. Place your running output in the next cell:  <span style="font-size:12px"> </span>

# %% [markdown]
# /home/ucdenver/hadoop-2.10.0/bin/hadoop jar Walmart.jar Walmart /user/srinath/input /user/srinath/output/1
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.hadoop.security.authentication.util.KerberosUtil (file:/home/ucdenver/hadoop-2.10.0/share/hadoop/common/lib/hadoop-auth-2.10.0.jar) to method sun.security.krb5.Config.getInstance()
# WARNING: Please consider reporting this to the maintainers of org.apache.hadoop.security.authentication.util.KerberosUtil
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# 23/02/23 23:32:27 INFO Configuration.deprecation: session.id is deprecated. Instead, use dfs.metrics.session-id
# 23/02/23 23:32:27 INFO jvm.JvmMetrics: Initializing JVM Metrics with processName=JobTracker, sessionId=
# 23/02/23 23:32:27 INFO jvm.JvmMetrics: Cannot initialize JVM Metrics with processName=JobTracker, sessionId= - already initialized
# 23/02/23 23:32:27 INFO mapred.FileInputFormat: Total input files to process : 1
# 23/02/23 23:32:27 INFO mapreduce.JobSubmitter: number of splits:1
# 23/02/23 23:32:27 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_local1222576318_0001
# 23/02/23 23:32:27 INFO mapreduce.Job: The url to track the job: http://localhost:8080/
# 23/02/23 23:32:27 INFO mapred.LocalJobRunner: OutputCommitter set in config null
# 23/02/23 23:32:27 INFO mapreduce.Job: Running job: job_local1222576318_0001
# 23/02/23 23:32:27 INFO mapred.LocalJobRunner: OutputCommitter is org.apache.hadoop.mapred.FileOutputCommitter
# 23/02/23 23:32:27 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
# 23/02/23 23:32:27 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 23/02/23 23:32:27 INFO mapred.LocalJobRunner: Waiting for map tasks
# 23/02/23 23:32:27 INFO mapred.LocalJobRunner: Starting task: attempt_local1222576318_0001_m_000000_0
# 23/02/23 23:32:27 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
# 23/02/23 23:32:27 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 23/02/23 23:32:28 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 23/02/23 23:32:28 INFO mapred.MapTask: Processing split: hdfs://localhost:54310/user/sivapriya_akumulla/input:0+12842546
# 23/02/23 23:32:28 INFO mapred.MapTask: numReduceTasks: 1
# 23/02/23 23:32:28 INFO mapred.MapTask: (EQUATOR) 0 kvi 26214396(104857584)
# 23/02/23 23:32:28 INFO mapred.MapTask: mapreduce.task.io.sort.mb: 100
# 23/02/23 23:32:28 INFO mapred.MapTask: soft limit at 83886080
# 23/02/23 23:32:28 INFO mapred.MapTask: bufstart = 0; bufvoid = 104857600
# 23/02/23 23:32:28 INFO mapred.MapTask: kvstart = 26214396; length = 6553600
# 23/02/23 23:32:28 INFO mapred.MapTask: Map output collector class = org.apache.hadoop.mapred.MapTask$MapOutputBuffer
# 23/02/23 23:32:28 INFO mapreduce.Job: Job job_local1222576318_0001 running in uber mode : false
# 23/02/23 23:32:28 INFO mapreduce.Job:  map 0% reduce 0%
# 23/02/23 23:32:28 INFO mapred.LocalJobRunner:
# 23/02/23 23:32:28 INFO mapred.MapTask: Starting flush of map output
# 23/02/23 23:32:28 INFO mapred.MapTask: Spilling map output
# 23/02/23 23:32:28 INFO mapred.MapTask: bufstart = 0; bufend = 443074; bufvoid = 104857600
# 23/02/23 23:32:28 INFO mapred.MapTask: kvstart = 26214396(104857584); kvend = 26096024(104384096); length = 118373/6553600
# 23/02/23 23:32:29 INFO mapred.MapTask: Finished spill 0
# 23/02/23 23:32:29 INFO mapred.Task: Task:attempt_local1222576318_0001_m_000000_0 is done. And is in the process of committing
# 23/02/23 23:32:29 INFO mapred.LocalJobRunner: hdfs://localhost:54310/user/sivapriya_akumulla/input:0+12842546
# 23/02/23 23:32:29 INFO mapred.Task: Task 'attempt_local1222576318_0001_m_000000_0' done.
# 23/02/23 23:32:29 INFO mapred.Task: Final Counters for attempt_local1222576318_0001_m_000000_0: Counters: 22
# 	File System Counters
# 		FILE: Number of bytes read=3324
# 		FILE: Number of bytes written=988016
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=12842546
# 		HDFS: Number of bytes written=0
# 		HDFS: Number of read operations=5
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=1
# 	Map-Reduce Framework
# 		Map input records=421571
# 		Map output records=29594
# 		Map output bytes=443074
# 		Map output materialized bytes=502268
# 		Input split bytes=104
# 		Combine input records=0
# 		Spilled Records=29594
# 		Failed Shuffles=0
# 		Merged Map outputs=0
# 		GC time elapsed (ms)=5
# 		Total committed heap usage (bytes)=526385152
# 	File Input Format Counters
# 		Bytes Read=12842546
# 23/02/23 23:32:29 INFO mapred.LocalJobRunner: Finishing task: attempt_local1222576318_0001_m_000000_0
# 23/02/23 23:32:29 INFO mapred.LocalJobRunner: map task executor complete.
# 23/02/23 23:32:29 INFO mapred.LocalJobRunner: Waiting for reduce tasks
# 23/02/23 23:32:29 INFO mapred.LocalJobRunner: Starting task: attempt_local1222576318_0001_r_000000_0
# 23/02/23 23:32:29 INFO output.FileOutputCommitter: File Output Committer Algorithm version is 1
# 23/02/23 23:32:29 INFO output.FileOutputCommitter: FileOutputCommitter skip cleanup _temporary folders under output directory:false, ignore cleanup failures: false
# 23/02/23 23:32:29 INFO mapred.Task:  Using ResourceCalculatorProcessTree : [ ]
# 23/02/23 23:32:29 INFO mapred.ReduceTask: Using ShuffleConsumerPlugin: org.apache.hadoop.mapreduce.task.reduce.Shuffle@2de943c1
# 23/02/23 23:32:29 INFO reduce.MergeManagerImpl: MergerManager: memoryLimit=375809632, maxSingleShuffleLimit=93952408, mergeThreshold=248034368, ioSortFactor=10, memToMemMergeOutputsThreshold=10
# 23/02/23 23:32:29 INFO reduce.EventFetcher: attempt_local1222576318_0001_r_000000_0 Thread started: EventFetcher for fetching Map Completion Events
# 23/02/23 23:32:29 INFO reduce.LocalFetcher: localfetcher#1 about to shuffle output of map attempt_local1222576318_0001_m_000000_0 decomp: 502264 len: 502268 to MEMORY
# 23/02/23 23:32:29 INFO reduce.InMemoryMapOutput: Read 502264 bytes from map-output for attempt_local1222576318_0001_m_000000_0
# 23/02/23 23:32:29 INFO reduce.MergeManagerImpl: closeInMemoryFile -> map-output of size: 502264, inMemoryMapOutputs.size() -> 1, commitMemory -> 0, usedMemory ->502264
# 23/02/23 23:32:29 INFO reduce.EventFetcher: EventFetcher is interrupted.. Returning
# 23/02/23 23:32:29 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 23/02/23 23:32:29 INFO reduce.MergeManagerImpl: finalMerge called with 1 in-memory map-outputs and 0 on-disk map-outputs
# 23/02/23 23:32:29 INFO mapred.Merger: Merging 1 sorted segments
# 23/02/23 23:32:29 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 502252 bytes
# 23/02/23 23:32:29 INFO reduce.MergeManagerImpl: Merged 1 segments, 502264 bytes to disk to satisfy reduce memory limit
# 23/02/23 23:32:29 INFO reduce.MergeManagerImpl: Merging 1 files, 502268 bytes from disk
# 23/02/23 23:32:29 INFO reduce.MergeManagerImpl: Merging 0 segments, 0 bytes from memory into reduce
# 23/02/23 23:32:29 INFO mapred.Merger: Merging 1 sorted segments
# 23/02/23 23:32:29 INFO mapred.Merger: Down to the last merge-pass, with 1 segments left of total size: 502252 bytes
# 23/02/23 23:32:29 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 23/02/23 23:32:29 INFO mapred.Task: Task:attempt_local1222576318_0001_r_000000_0 is done. And is in the process of committing
# 23/02/23 23:32:29 INFO mapred.LocalJobRunner: 1 / 1 copied.
# 23/02/23 23:32:29 INFO mapred.Task: Task attempt_local1222576318_0001_r_000000_0 is allowed to commit now
# 23/02/23 23:32:29 INFO output.FileOutputCommitter: Saved output of task 'attempt_local1222576318_0001_r_000000_0' to hdfs://localhost:54310/user/sivapriya_akumulla/output/1/_temporary/0/task_local1222576318_0001_r_000000
# 23/02/23 23:32:29 INFO mapred.LocalJobRunner: reduce > reduce
# 23/02/23 23:32:29 INFO mapred.Task: Task 'attempt_local1222576318_0001_r_000000_0' done.
# 23/02/23 23:32:29 INFO mapred.Task: Final Counters for attempt_local1222576318_0001_r_000000_0: Counters: 29
# 	File System Counters
# 		FILE: Number of bytes read=1007892
# 		FILE: Number of bytes written=1490284
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=12842546
# 		HDFS: Number of bytes written=37675
# 		HDFS: Number of read operations=8
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=3
# 	Map-Reduce Framework
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=2291
# 		Reduce shuffle bytes=502268
# 		Reduce input records=29594
# 		Reduce output records=2291
# 		Spilled Records=29594
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=0
# 		Total committed heap usage (bytes)=526385152
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Output Format Counters
# 		Bytes Written=37675
# 23/02/23 23:32:29 INFO mapred.LocalJobRunner: Finishing task: attempt_local1222576318_0001_r_000000_0
# 23/02/23 23:32:29 INFO mapred.LocalJobRunner: reduce task executor complete.
# 23/02/23 23:32:29 INFO mapreduce.Job:  map 100% reduce 100%
# 23/02/23 23:32:29 INFO mapreduce.Job: Job job_local1222576318_0001 completed successfully
# 23/02/23 23:32:29 INFO mapreduce.Job: Counters: 35
# 	File System Counters
# 		FILE: Number of bytes read=1011216
# 		FILE: Number of bytes written=2478300
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=25685092
# 		HDFS: Number of bytes written=37675
# 		HDFS: Number of read operations=13
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=4
# 	Map-Reduce Framework
# 		Map input records=421571
# 		Map output records=29594
# 		Map output bytes=443074
# 		Map output materialized bytes=502268
# 		Input split bytes=104
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=2291
# 		Reduce shuffle bytes=502268
# 		Reduce input records=29594
# 		Reduce output records=2291
# 		Spilled Records=59188
# 		Shuffled Maps =1
# 		Failed Shuffles=0
# 		Merged Map outputs=1
# 		GC time elapsed (ms)=5
# 		Total committed heap usage (bytes)=1052770304
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=12842546
# 	File Output Format Counters
# 		Bytes Written=37675

# %% [markdown]
# ### 4. Place the first 10 rows of your exit in the next cell:  <span style="font-size:12px">(Hint: take a look at the _wc_ linux command) </span>

# %% [markdown]
# ucdenver@CSCI-SIMON-2:~/sivapriya_akumulla$ sudo -u ucdenver /home/ucdenver/hadoop-2.10.0/bin/hadoop dfs -cat /user/sivapriya_akumulla/output/1/* | head -n 10
# DEPRECATED: Use of this script to execute hdfs command is deprecated.
# Instead use the hdfs command for it.
#
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.hadoop.security.authentication.util.KerberosUtil (file:/home/ucdenver/hadoop-2.10.0/share/hadoop/common/lib/hadoop-auth-2.10.0.jar) to method sun.security.krb5.Config.getInstance()
# WARNING: Please consider reporting this to the maintainers of org.apache.hadoop.security.authentication.util.KerberosUtil
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# 1-2010-02	53505
# 1-2010-03	59262
# 1-2010-04	91636
# 1-2010-05	27149
# 1-2010-06	8741
# 1-2010-07	19791
# 1-2010-09	38610
# 1-2010-10	53462
# 1-2010-12	95271
# 1-2011-01	21034
# cat: Unable to write to output stream.

# %%
pip install google
# Out:
# ...
#   Using cached google-3.0.0-py2.py3-none-any.whl (45 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>NB:</b> CLOSE YOUR TERMINAL BEFORE CONTINUING TO SECTION 2
# </div>

# %% [markdown]
# <hr style="border-top: 5px solid purple; margin-top: 1px; margin-bottom: 1px"></hr>

# %% [markdown]
# ***
# # <span style="font-size:35px;color:#3665af">Section 2: Spanner </span>
#
# <hr>
# In this section we will practice how to use Google's Spanner database.
#
# <div class="alert alert-block alert-info">
# <b>NOTE:</b> Your Google cloud account should be ready to deploy services. See the GoogleCloud_Setup document on the Canvas assignment page.
# </div>
#
#
# ### <span style="color:green"> Create a Spanner Instance:</span>
# <span style="font-size:15px;color:purple">Detailed instructions in the document </span>
#
# - Create a spanner instace, and annotate the Instance ID.
# - We will use lab1-section2 as instance id in this assignment; if you are using another id, you need to change it in the connection settings.
# - For this test, configuring one node will suffice.

# %% [markdown]
# ### <span style="color:green">Install the Python Client: </span>
#
# <div class="alert alert-block alert-success">
#
# We need to have the google-cloud library installed in our system.<br>
# Open the terminal under <b>New >> Terminal</b><br>
# Then execute the following pip commands to install the client library.
#
#
#
# ``` bash
# $> pip install google
# $> pip install google-cloud
# $> pip install google-cloud-datastore --user
# $> pip install google-cloud-spanner
# $> pip install google-api-core
# $> pip install google-cloud-storage
# ```
#
# </div>

# %%
pip install google-cloud-storage
# Out:
# ...
#   Using cached google_cloud_storage-2.7.0-py2.py3-none-any.whl (110 kB)
# ...
#   Using cached google_resumable_media-2.4.1-py2.py3-none-any.whl (77 kB)
# ...
#   Using cached google_crc32c-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (32 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install google-api-core
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install google-cloud-datastore --user --no-warn-script-location
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install google-cloud
# Out:
# ...
#   Using cached google_cloud-0.34.0-py2.py3-none-any.whl (1.8 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install google-cloud-spanner
# Out:
# ...
#   Using cached google_cloud_spanner-3.27.1-py2.py3-none-any.whl (300 kB)
# ...
#   Using cached grpc_google_iam_v1-0.12.6-py2.py3-none-any.whl (26 kB)
# ...
#   Using cached sqlparse-0.4.3-py3-none-any.whl (42 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>NB:</b> PLEASE RESTART THE KERNEL (Kernel -> Restart)
# </div>

# %% [markdown]
# ### <span style="color:green">Get the Service Account File:</span>
# As mentioned in the cloud setup instructions, you need to generate a token file so you will be able to connect to spanner. Refer to that document for help. <br>
# Here is the summary of the steps.
# 1. Go to APIS & Services
# 2. Go to Credentials
# 3. Select Create Credentials, and choose Service account key.
# 4. Select Compute Engine default service account and Key type JSON. Then Create.
# 5. Pick the file that was automatically downloaded, and store it in your Assignment1 directory on jupyterhub.

# %% [markdown]
# ### <span style="color:green"> Beofore you perform the excercise for this section (at the bottom of this section), let's run through an example. Run the following cells to review the example: </span>

# %%
# Imports the Google Cloud Client Library.
from google.cloud import spanner

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>NB:</b> Replace the "bigdatasystems-fall2021-325819-e64d042b5422.json" name below with the one you copied to your Assignment1 directory (bigdata > Assignment1 > *.json)
# </div>

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="just-amp-378719-f3bc1cae4c5d.json"

# %% [markdown]
# You can learn more about creating instances and using Spanner with Python at [Google Documentation](https://cloud.google.com/spanner/docs/getting-started/python/)

# %%
def explicit():
    ## Function to connect to spanner
    from google.cloud import storage

    # Explicitly use service account credentials by specifying the private key
    # file.
    storage_client = storage.Client.from_service_account_json(JSON_SERVICE_KEY)

    # Make an authenticated API request
    buckets = list(storage_client.list_buckets())
    print(buckets)

# %% [markdown]
# You can get help about authentication at [Google Documentation](https://cloud.google.com/docs/authentication/production#auth-cloud-explicit-python)

# %% [markdown]
# #### <span style="color:Green">Using Spanner Client:</span>

# %%
# Instantiate a client.
spanner_client = spanner.Client()

# Your Cloud Spanner instance ID.
instance_id = 'lab-1-section-2'

# Get a Cloud Spanner instance by ID.
instance = spanner_client.instance(instance_id)

# Your Cloud Spanner database ID.
database_id = 'lab1-db'           # If you did not create the database already, createit using the cloud console

# Get a Cloud Spanner database by ID.
database = instance.database(database_id)

# Execute a simple SQL statement.
with database.snapshot() as snapshot:
    results = snapshot.execute_sql('SELECT current_date')

    for row in results:
        print(row)
# Out:
# [datetime.date(2023, 2, 24)]

# %% [markdown]
# If you didn't recevie an error and the current date was displayed, it means that at this point we're connected to our Spanner database.<rb>
#
# #### <span style="color:Green">Create a couple of tables:</span>
#
# This may take a minute. If you use your google cloud dashboard, you can see the two new tables as you refresh the page.

# %%
operation =database.update_ddl(ddl_statements=[
    """CREATE TABLE Singers (
        SingerId     INT64 NOT NULL,
        FirstName    STRING(1024),
        LastName     STRING(1024),
        SingerInfo   BYTES(MAX)
    ) PRIMARY KEY (SingerId)"""
    ,
    """CREATE TABLE Albums (
        SingerId     INT64 NOT NULL,
        AlbumId      INT64 NOT NULL,
        AlbumTitle   STRING(MAX)
    ) PRIMARY KEY (SingerId, AlbumId),
      INTERLEAVE IN PARENT Singers ON DELETE CASCADE"""
])

#operation = database.create()

print('Waiting for operation to complete...')
operation.result()

print('Created tables in database {} on instance {}'.format( database_id, instance_id))
# Out:
# Waiting for operation to complete...
# Created tables in database lab1-db on instance lab-1-section-2

# %% [markdown]
# ### QUESTION:
# **_In which line the command that creates the database is actually executed on Spanner?_** Explain briefly.

# %% [markdown]
# operation=database.create() will be the command that creates the database, but the line over here is commented. Hence, there is no direct command is written that creates database.
# However as we have created our database already in the spanner operation=database.update_ddl will update the database with the tables namely singers and albums. In this case if there is no database that is already existing, code will raise an exception. Now, using update_DDl the table will be updated.

# %% [markdown]
# #### <span style="color:Green">Now let's insert some data:</span>

# %%
"""Inserts sample data into the given database.
   The database and table must already exist.
"""

with database.batch() as batch:
    batch.insert(
        table='Singers',
        columns=('SingerId', 'FirstName', 'LastName',),
        values=[
            (1, u'Marc', u'Richards'),
            (2, u'Catalina', u'Smith'),
            (3, u'Alice', u'Trentor'),
            (4, u'Lea', u'Martin'),
            (5, u'David', u'Lomond')])
    batch.commit
    
    batch.insert(
        table='Albums',
        columns=('SingerId', 'AlbumId', 'AlbumTitle',),
        values=[
            (1, 1, u'Total Junk'),
            (1, 2, u'Go, Go, Go'),
            (2, 1, u'Green'),
            (2, 2, u'Forever Hold Your Peace'),
            (2, 3, u'Terrified')])
    batch.commit
print('Inserted data.')
# Out:
# Inserted data.

# %% [markdown]
# ### QUESTION:
# **_How many statements were executed in Spanner?_** Explain briefly.

# %% [markdown]
# There are four statements that were executed in the database, the batch.insert command runs once for inserting the data into the tables and the batch.commit() tells us that two batches were created and were committed on separately. Hence two DML statements were run when insert operation was executed separately for singers and albums table, in a similar way commit operation.

# %% [markdown]
# #### <span style="color:Green">Here we query the database:</span>

# %%
"""Queries sample data from the database using SQL."""


with database.snapshot() as snapshot:
    results = snapshot.execute_sql(
        'SELECT SingerId, AlbumId, AlbumTitle FROM Albums')
    
    display(results)
    
    for row in results:
        display(row)
        print('SingerId: {}, AlbumId: {}, AlbumTitle: {}'.format(*row))
        #print("SingerId: ",row[0],", AlbumId: ",row[1],", AlbumTitle: ",row[2], )
# Out:
# [1, 1, 'Total Junk']
# SingerId: 1, AlbumId: 1, AlbumTitle: Total Junk
# [1, 2, 'Go, Go, Go']
# SingerId: 1, AlbumId: 2, AlbumTitle: Go, Go, Go
# [2, 1, 'Green']
# SingerId: 2, AlbumId: 1, AlbumTitle: Green
# [2, 2, 'Forever Hold Your Peace']
# SingerId: 2, AlbumId: 2, AlbumTitle: Forever Hold Your Peace
# [2, 3, 'Terrified']
# SingerId: 2, AlbumId: 3, AlbumTitle: Terrified

# %% [markdown]
# ### QUESTIONS:
# 1. **What kind of object is _results_?**
# 2. **What kind of object is _row_?**
# 3. **How is row being accessed?** (Tip: take a look at the commented line)

# %% [markdown]
# 1) the object results is a cursor object that is run through rows iterated, it is the results of running an SQL query and is returned by the query.
# 2) row is a tuple that has all the values of a row stored in the object results.
# 3) the output is given after formatting the data into string, the values or data are accessed using the method tuple indexing. In which, row[0] is singer id, row[1] is album id and row[2] is album title

# %%
"""Reads sample data from the database."""

with database.snapshot() as snapshot:
    keyset = spanner.KeySet(all_=True)
    results = snapshot.read(
        table='Albums',
        columns=('SingerId', 'AlbumId', 'AlbumTitle',),
        keyset=keyset,)

    for row in results:
        print('SingerId: {}, AlbumId: {}, AlbumTitle: {}'.format(*row))
# Out:
# SingerId: 1, AlbumId: 1, AlbumTitle: Total Junk
# SingerId: 1, AlbumId: 2, AlbumTitle: Go, Go, Go
# SingerId: 2, AlbumId: 1, AlbumTitle: Green
# SingerId: 2, AlbumId: 2, AlbumTitle: Forever Hold Your Peace
# SingerId: 2, AlbumId: 3, AlbumTitle: Terrified

# %% [markdown]
# ### QUESTIONS
# **_What is the difference between the first and second part of the code?_**

# %% [markdown]
# For the above showb code the first part of the code creates a connection with the database and creates a snapshot of the recent state whereas the second part

# %% [markdown]
# #### <span style="color:Green">Now let's load some interesting data:</span>

# %%
import pandas as pd
import datetime
from time import time

# %%
# Instantiate a client.
spanner_client = spanner.Client()

# Your Cloud Spanner instance ID.
instance_id = 'lab-1-section-2'

# Get a Cloud Spanner instance by ID.
instance = spanner_client.instance(instance_id)

# Your Cloud Spanner database ID.
database_id = 'lab-db'                             ## Create new Database

# Get a Cloud Spanner database by ID.
database = instance.database(database_id)

# Execute a simple SQL statement.
with database.snapshot() as snapshot:
    results = snapshot.execute_sql('SELECT current_date')

    for row in results:
        print(row)
# Out:
# [datetime.date(2023, 2, 24)]

# %%
start_time=time()
operation =database.update_ddl(ddl_statements=[
    """CREATE TABLE RadiationMeasurements
        (
           CapturedTime timestamp,
           latitude float64,
           longitude float64,
           Value float64,
           Unit String(2048),
           Location String(2048),
           DeviceID String(2048),
           MD5Sum String(2048),
           Height String(2048),
           Surface String(2048),
           Radiation String(2048),
           UploadedTime timestamp,
           LoaderID float64
        )PRIMARY KEY (CapturedTime,Latitude,Longitude,Location,UploadedTime,MD5Sum)"""
])

# operation = database.create()

print('Waiting for operation to complete...')
operation.result()

print('Created tables in database {} on instance {}'.format(
    database_id, instance_id))

end_time=time()

print ("run time:",end_time-start_time)
# Out:
# Waiting for operation to complete...
# ---------------------------------------------------------------------------
# FailedPrecondition                        Traceback (most recent call last)
# Cell In[25], line 24
#      21 # operation = database.create()
#      23 print('Waiting for operation to complete...')
# ---> 24 operation.result()
#      26 print('Created tables in database {} on instance {}'.format(
#      27     database_id, instance_id))
#      29 end_time=time()
#
# File ~/.local/lib/python3.10/site-packages/google/api_core/future/polling.py:261, in PollingFuture.result(self, timeout, retry, polling)
#     256 self._blocking_poll(timeout=timeout, retry=retry, polling=polling)
#     258 if self._exception is not None:
#     259     # pylint: disable=raising-bad-type
#     260     # Pylint doesn't recognize that this is valid in this case.
# --> 261     raise self._exception
#     263 return self._result
#
# ...

# %%
df_Measures        = pd.read_csv("radiation.measurements.sample.csv")

# %%
df_Measures.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4999 entries, 0 to 4998
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Captured Time  4999 non-null   object
#  1   Latitude       4999 non-null   float64
#  2   Longitude      4999 non-null   float64
#  3   Value          4999 non-null   float64
#  4   Unit           4999 non-null   object
#  5   Location Name  39 non-null     object
#  6   Device ID      4338 non-null   float64
#  7   MD5Sum         4999 non-null   object
#  8   Height         3969 non-null   float64
#  9   Surface        0 non-null      float64
#  10  Radiation      0 non-null      float64
#  11  Uploaded Time  4999 non-null   object
#  12  Loader ID      661 non-null    float64
# dtypes: float64(8), object(5)
# memory usage: 507.8+ KB

# %%
myData=[]
for index,row in df_Measures[0:5].iterrows():
    aDateTime = datetime.datetime.strptime(row["Captured Time"], '%Y-%m-%d %H:%M:%S')
    display('Row: {}, Timestamp: {} Lat/Lon:{}/{}'.format(index,aDateTime,row["Latitude"],row["Longitude"]))
    myData.append( (index,aDateTime)  )
myData
# Out:
# 'Row: 0, Timestamp: 2020-02-03 17:00:00 Lat/Lon:37.507551666667/139.94117'
# 'Row: 1, Timestamp: 2020-02-03 11:00:00 Lat/Lon:37.505445/0.016666666666667'
# 'Row: 2, Timestamp: 2020-02-03 11:00:00 Lat/Lon:37.50725/139.94'
# 'Row: 3, Timestamp: 2020-02-01 03:00:00 Lat/Lon:34.066486666667/-118.89521666667'
# 'Row: 4, Timestamp: 2020-02-01 01:00:00 Lat/Lon:37.673233333333/140.06666666667'
# [(0, datetime.datetime(2020, 2, 3, 17, 0)),
#  (1, datetime.datetime(2020, 2, 3, 11, 0)),
#  (2, datetime.datetime(2020, 2, 3, 11, 0)),
#  (3, datetime.datetime(2020, 2, 1, 3, 0)),
#  (4, datetime.datetime(2020, 2, 1, 1, 0))]

# %%
# Out:
# Index(['Captured Time', 'Latitude', 'Longitude', 'Value', 'Unit',
#        'Location Name', 'Device ID', 'MD5Sum', 'Height', 'Surface',
#        'Radiation', 'Uploaded Time', 'Loader ID'],
#       dtype='object')

# %%
#     ****************************************************************
#     TO-DO: Write here a while/for to insert the Primary key data for the first 10 rows. 
#     ****************************************************************

# --Hints:
#     Adapt the code from the sample. 
#     Generate an array inserting tuples (you should use an array and the function append )


### Write your code here.
import pandas as pd

print(df_Measures.columns) #To get to know the column names

primary_key_data=[]
for index,row in df_Measures.head(10).iterrows(): #Fetching the first 10 data
    aDateTime = datetime.datetime.strptime(row["Captured Time"], '%Y-%m-%d %H:%M:%S')
    primary_key_data.append((aDateTime,
                row["Longitude"],
                row["Latitude"],
                row["Location Name"],               
                row["MD5Sum"]
                ))
primary_key_data=tuple(primary_key_data)
print("")
print("Task Completed")

key_table=pd.DataFrame(primary_key_data,columns=['Captured Time','Longitude ','Latitude ','Location Name', 'MD5Sum'])
print("") #displaying the data in key_table
print(key_table)
# Out:
# Index(['Captured Time', 'Latitude', 'Longitude', 'Value', 'Unit',
#        'Location Name', 'Device ID', 'MD5Sum', 'Height', 'Surface',
#        'Radiation', 'Uploaded Time', 'Loader ID'],
#       dtype='object')
#
# Task Completed
#
#         Captured Time  Longitude   Latitude   Location Name  \
# 0 2020-02-03 17:00:00  139.941170  37.507552            NaN
# 1 2020-02-03 11:00:00    0.016667  37.505445            NaN
# 2 2020-02-03 11:00:00  139.940000  37.507250            NaN
# 3 2020-02-01 03:00:00 -118.895217  34.066487            NaN
# 4 2020-02-01 01:00:00  140.066667  37.673233            NaN
# 5 2020-02-01 01:00:00  140.079895  37.674782            NaN
# 6 2020-01-12 19:00:00  139.925478  37.517902            NaN
# 7 2020-01-12 19:00:00  140.726853  37.737123            NaN
# 8 2020-01-12 19:00:00  140.116577  37.539610            NaN
# 9 2020-01-12 19:00:00  140.703412  37.755880            NaN
#
#                              MD5Sum
# 0  6449bbf7ce3b30a8e05bc23a0bc40644
# ...

# %% [markdown]
# # <span style="color:#5DB664">DELETE YOUR SPANNER INSTANCE AS WHEN YOU FINISH WITH REVIEW OF THE ABOVE EXAMPLE!</span>

# %% [markdown]
# <hr style="border-top: 1px solid red; margin-top: 20px; margin-bottom: 1px"></hr>
#
# # <span style="color:RED">Exercise: </span> Yelp Dataset
#
# <hr style="border-top: 1px solid red; margin-top: 20px; margin-bottom: 1px"></hr>
#
# Similar to the example above, we are going to be using the Yelp competition dataset available [here](https://www.kaggle.com/yelp-dataset/yelp-dataset/data). <br>
# You should:
# 1. Download the dataset to your machine.
# 2. Create a new database.
# 3. Create the tables necessary, with the proper interleaving configuration to store the business and reviews.
# 4. Load the yelp_business dataset.
# 5. Load 10% of the yelp_review dataset.
#
# Hints:
# - You probably want to do several batchs. You can do that by using the **[start:end]** operator for the dataframes.
# - You may need to review the documentation for the [Spanner SQL](https://cloud.google.com/spanner/docs/query-syntax)
#
# ## Questions:
# 1. Report the time for loading each dataset.
# 2. Compare the time to load the rows for the business and the reviews datasets.
# 3. List the top 10 better/most rated businesses in Colorado. To simplify this, let's assume that the best rated business is the one with the higher sum of ratings.

# %%
## PLACE YOUR CODE STARTING THIS POINT. 
import pandas as pd
import datetime
from time import time

# %%
spanner_client = spanner.Client()
instance_id = 'lab1-section2'
instance = spanner_client.instance(instance_id)
database_id = 'lab-db'                             
database = instance.database(database_id)
with database.snapshot() as snapshot:
    results = snapshot.execute_sql('SELECT current_date')

    for row in results:
        print(row)
# Out:
# [datetime.date(2023, 2, 24)]

# %%
start=time()
operation =database.update_ddl(ddl_statements=[
    """CREATE table yelp_buisness
    (buisness_id String(2048),
    name String(2048),
    address String(2048),
    city String(2048),
    state String(2048),
    postal_code String(2048),
    Latitude float64,
    Longitude float64,
    stars float64,
    review_count int64,
    is_open int64,
    attributes Struct<ByAppointmentOnly bool>,
    categories array<string(100)>,
    hours String(1024)
    ) PRIMARY KEY (buisness_id)"""
])

operation =database.update_ddl(ddl_statements=[
    """CREATE table yelp_review
    (review_id String(2048),
    user_id String(2048),
    buisness_id String(2048),
    stars int64,
    useful int64,
    funny int64,
    cool int64,
    text String(MAX),
    date String(1024)
    ) PRIMARY KEY(review_id)
    """
])
print("It may take a while to complete the operation")
operation.result()

print('Created table buisness in database {} on instance {}'.format(
    database_id, instance_id))

end=time()

print ("run time:",end-start)
# Out:
# It may take a while to complete the operation
# Created table buisness in database lab-db on instance lab1-section2
# run time: 2.7604658603668213

# %%
#loading the data into the tables - buisness table.
s1=time()
b_table=pd.read_json('yelp_academic_dataset_business.json')
def b_load(rows):
    with database.batch() as batch:
        for i in rows.intertuples(index=false):
            batch.insert(
            table='yelp_buisness',
            columns=('buisness_id','name','address','city','state','postal_code','latitude',
                     'longitude','stars','review_count','is_open','attributes','categories','hours'),
            values=[(i.buisness_id,i.name,i.address,i.city,i.state,i.postal_code,i.latitude,
                    i.longitude,i.stars,i.review_count,i.is_open,i.attributes,i.categories,i.hours)])
b_load(b_table)
e1=time()

s2=time()
#loading the data into table - review table.
r_table=pd.read_json('yelp_academic_dataset_review.json')
r_table=r_table.sample(frac=0.1)
def r_load(rows):
    with database.batch() as batch:
        for j in rows.intertuples(index=false):
            batch.insert(
            table='yelp_review',
            columns=('review_id','user_id','buisness_id','stars','useful','funny','cool','text','date'),
            values=[(j.review_id,j.user_id,j.buisness_id,j.stars,j.useful,j.funny,j.cool,j.text,j.date)])
r_load(r_table)
e2=time()

print("Time for loading table-1: Buisness table is", e1-s1)

print("Time for loading table-2: Review table is ", e2-s2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 3
#       1 #loading the data into the tables - buisness table.
#       2 s1=time()
# ----> 3 b_table=pd.read_json('yelp_academic_dataset_business.json')
#       4 def b_load(rows):
#       5     with database.batch() as batch:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
# ...

# %%
with database.snapshot() as snapshot:
    results = snapshot.execute_sql(
        'SELECT name, city, review_count FROM yelp_buisness
         where state='CO' 
         order by review_count DESC, stars DESC 
         LIMIUT 10')
    
    display(results)

# %% [markdown]
# <hr style="border-top: 5px solid purple; margin-top: 1px; margin-bottom: 1px"></hr>

# %% [markdown]
# ***
# # <span style="font-size:35px;color:#3665af">Section 3: Bigtable </span>
#
# <hr>
# In this section we will practice how to use Google's Bigtable database.
#
# <div class="alert alert-block alert-info">
# <b>NOTE:</b> Your Google cloud account should be ready to deploy services. See the GoogleCloud_Setup document on the Canvas assignment page.
# </div>
#
# ### <span style="color:green"> Create a Bigtable Instance:</span>
# <span style="font-size:15px;color:purple">Detailed instructions in the document </span>
# - Create a development Bigtable instace, and annotate the Instance ID.
# - We will use "lab1-section3" instance id in this assignment; if you are using another id, you need to change in the connection settings.
# - For this test, use a development instance, which has only one node but is way cheaper.
#
#
# ### <span style="color:green"> Get the Service Account File:</span>
#
# As mentioned in the cloud set up instructions, you need to generate a token file so you will be able to connect to bigtable. Refer to that document for help.
#
# Documentation [here](http://google-cloud-python.readthedocs.io/en/latest/bigtable/usage.html)

# %% [markdown]
# ### <span style="color:green">Installing the Python Client: </span>
#
# <div class="alert alert-block alert-success">
#
# We need to have the google cloud library installed in our system.<br>
# Execute the following pip command in your terminal to install the client library.
#
# ```
# $> pip install google-cloud-bigtable --user
# $> pip install google-cloud-happybase
# ```
#
# </div>

# %%
pip install google-cloud-bigtable --user
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install google-cloud-happybase
# Out:
# E0225 03:00:48.404092874   13703 backup_poller.cc:136]                 Run client channel backup poller: UNKNOWN:pollset_work {created_time:"2023-02-25T03:00:48.403952835+00:00", children:[UNKNOWN:Bad file descriptor {created_time:"2023-02-25T03:00:48.403874188+00:00", errno:9, os_error:"Bad file descriptor", syscall:"epoll_wait"}]}
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### <span style="color:green"> Beofore you perform the excercise for this section (at the bottom of this section), let's run through an example. Run the following cells to review the example: </span>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>NB:</b> Replace the "bigdatasystems-fall2021-325819-e64d042b5422.json" name below with the one you copied to your Assignment1 directory (bigdata > Assignment1 > *.json)
# </div>

# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="just-amp-378719-f3bc1cae4c5d.json"

# %% [markdown]
# You can learn more about creating instances and using Spanner with Python at [Google Documentation](https://cloud.google.com/spanner/docs/getting-started/python/)

# %%
def explicit():
    ## Function to connect to spanner
    from google.cloud import storage

    # Explicitly use service account credentials by specifying the private key
    # file.
    storage_client = storage.Client.from_service_account_json(JSON_SERVICE_KEY)

    # Make an authenticated API request
    buckets = list(storage_client.list_buckets())
    print(buckets)

# %% [markdown]
# You can get help about authentication at [Google Documentation](https://cloud.google.com/docs/authentication/production#auth-cloud-explicit-python)

# %% [markdown]
# #### <span style="color:Green">Using Bigdata Client:</span>

# %%
instance_id = "lab1-section3"

# %%
# Imports the Google Cloud Client Library.
from google.cloud import bigtable

# The client must be created with admin=True because it will create a table.
client     = bigtable.Client(admin=True)
instance   = client.instance(instance_id)

# %% [markdown]
# If you didn't receive an error, it means that at this point we're connected to our Bigtable database else you should follow instruction in Google Cloud document<rb>
#
# #### <span style="color:Green">Let's create a table:</span>

# %%
table_name  = "greetings"
print('Creating the {} table.'.format(table_name))

table = instance.table(table_name)
table.create()

column_family_name = 'cf1'
cf1 = table.column_family(column_family_name)
cf1.create()

#table.delete()  #to delete the table.

print("done!")
### WARNING
#
## You will get an error the first time saying that you did not enable admin api. 
## A link will be given. Follow it and enable the API And retry.
# Out:
# Creating the greetings table.
# done!

# %% [markdown]
# #### <span style="color:Green">Now we insert the data:</span>

# %%
print('Writing some greetings to the table.')
column_name = 'greeting'.encode('utf-8')
greetings = [
    'Hello World!',
    'Hello Cloud Bigtable!',
    'Hello Bigtable with Python!',
]

for i, value in enumerate(greetings):
    row_key = 'greeting{}'.format(i)
    row = table.row(row_key)
    row.set_cell(   
                    column_family_name,
                    column_name,
                    value.encode('utf-8')
                )
    row.commit()
    

print('done!')
# Out:
# Writing some greetings to the table.
# done!

# %% [markdown]
# #### <span style="color:Green">Next we read the data:</span>

# %%
print('Getting a single greeting by row key.')
key = 'greeting0'

row = table.read_row(key.encode('utf-8'))

value = row.cells[column_family_name][column_name][0].value

print('\t{}: {}'.format(key, value.decode('utf-8')))
# Out:
# Getting a single greeting by row key.
# 	greeting0: Hello World!

# %%
print('Scanning for all greetings:')
partial_rows = table.read_rows()
partial_rows.consume_all()

for row_key, row in partial_rows.rows.items():
    key = row_key.decode('utf-8')
    cell = row.cells[column_family_name][column_name][0]
    value = cell.value.decode('utf-8')
    print('\t{}: {}'.format(key, value))
# Out:
# Scanning for all greetings:
# 	greeting0: Hello World!
# 	greeting1: Hello Cloud Bigtable!
# 	greeting2: Hello Bigtable with Python!

# %% [markdown]
# <hr>

# %% [markdown]
# #### <span style="color:Green">Using Happybase Client:</span>

# %%
# Imports the Google Cloud Client Library.
from google.cloud import happybase

# The client must be created with admin=True because it will create a table.

#client     = bigtable.Client(project=project_id, admin=True)
client = bigtable.Client(admin=True)
instance   = client.instance(instance_id)
connection = happybase.Connection(instance=instance)

# %% [markdown]
# If you didn't receive an error, it means that at this point we're connected to our Bigtable database.<rb>
#
# #### <span style="color:Green">Let's create a table:</span>

# %%
table_name  = "greetings2"
print('Creating the {} table.'.format(table_name))
column_family_name = 'cf1'
connection.create_table(    table_name,
                            {
                                column_family_name: dict()     # Use default options.
                            }
                       )
### WARNING
#
## You will get an error the first time saying that you did not enable admin api. 
## A link will be given. Follow it and enable the API And retry.
# Out:
# Creating the greetings2 table.

# %% [markdown]
# #### <span style="color:Green">Now we insert data:</span>

# %%
print('Writing some greetings to the table.')
table = connection.table(table_name)
column_name = '{fam}:greeting'.format(fam=column_family_name)
greetings = [
    'Hello World!',
    'Hello Cloud Bigtable!',
    'Hello HappyBase!',
]

for i, value in enumerate(greetings):
    row_key = 'greeting{}'.format(i)
    table.put(row_key, {(column_name).encode('utf-8'): value.encode('utf-8')})

print('done!')
# Out:
# Writing some greetings to the table.
# done!

# %% [markdown]
# #### <span style="color:Green">And now we read the data back:</span>

# %%
print('Getting a single greeting by row key.')
key = 'greeting0'.encode('utf-8')
row = table.row(key)
print('\t{}: {}'.format(key, row[column_name.encode('utf-8')]))
# Out:
# Getting a single greeting by row key.
# 	b'greeting0': b'Hello World!'

# %%
print('Scanning for all greetings:')

for key, row in table.scan():
    print('\t{}: {}'.format(key, row[column_name.encode('utf-8')]))

#     print('Deleting the {} table.'.format(table_name))
#     connection.delete_table(table_name)
# Out:
# Scanning for all greetings:
# 	b'greeting0': b'Hello World!'
# 	b'greeting1': b'Hello Cloud Bigtable!'
# 	b'greeting2': b'Hello HappyBase!'

# %%
connection.close()

# %% [markdown]
# <hr>

# %% [markdown]
# #### <span style="color:Green">Finally let's insert some more interesting data; here we will use the bigtable client but it can be done using happybase too:</span>

# %%
import pandas as pd
import datetime
from time import time
import math

# %%
df_Measures        = pd.read_csv("radiation.measurements.sample.csv",keep_default_na=False)

# %%
df_Measures
# Out:
#             Captured Time   Latitude   Longitude  Value    Unit Location Name  \
# 0     2020-02-03 17:00:00  37.507552  139.941170   72.0     cpm
# 1     2020-02-03 11:00:00  37.505445    0.016667   68.0     cpm
# 2     2020-02-03 11:00:00  37.507250  139.940000   55.0     cpm
# 3     2020-02-01 03:00:00  34.066487 -118.895217   50.0     cpm
# 4     2020-02-01 01:00:00  37.673233  140.066667   48.0     cpm
# ...                   ...        ...         ...    ...     ...           ...
# 4994  2017-12-03 21:41:47  37.496139  140.986419  163.0     cpm
# 4995  2017-12-03 21:41:41  37.329250  140.978431   10.5  status
# 4996  2017-12-03 21:41:39  38.403620 -122.818470   21.6  status
# 4997  2017-12-03 21:41:38  38.403620 -122.818470   10.0     cpm
# 4998  2017-12-03 21:41:38  38.403620 -122.818470   41.0     cpm
#
#      Device ID                            MD5Sum Height Surface Radiation  \
# 0               6449bbf7ce3b30a8e05bc23a0bc40644
# ...

# %%
# The client must be created with admin=True because it will create a table.
client     = bigtable.Client(admin=True)
instance   = client.instance(instance_id)

# %%
table_name  = "RadiationMeasurements"
table_columns = [
                    ("time","Captured Time"),("time","Uploaded Time"),
                    ("location","Latitude"),("location","Longitude"),("location","Height"),
                    ("measure","Value"),("measure","Unit"),
                    ("device","Device ID")
                ]

print('Creating the {} table.'.format(table_name))

RadiationMeasurements = instance.table(table_name)
RadiationMeasurements.create()


columnFamilies = []
for aColumn in table_columns:
    columnFamilies.append(aColumn[0])
columnFamilies = list(set(columnFamilies))

for aColumnFamily in columnFamilies:
    cf = RadiationMeasurements.column_family(aColumnFamily)
    cf.create()
     

print("done!")
### WARNING
#
## You will get an error the first time saying that you did not enable admin api. 
## A link will be given. Follow it and enable the API And retry.
# Out:
# Creating the RadiationMeasurements table.
# done!

# %%
columnFamilies
# Out:
# ['measure', 'time', 'location', 'device']

# %%
column_family_list = RadiationMeasurements.list_column_families()
print(column_family_list)
# Out:
# {'time': <google.cloud.bigtable.column_family.ColumnFamily object at 0x7fe2096d6fe0>, 'location': <google.cloud.bigtable.column_family.ColumnFamily object at 0x7fe2096d72e0>, 'device': <google.cloud.bigtable.column_family.ColumnFamily object at 0x7fe2096d79a0>, 'measure': <google.cloud.bigtable.column_family.ColumnFamily object at 0x7fe2096d72b0>}

# %%
#RadiationMeasurements.delete()   #UNCOMMENT IF YOU NEED TO DROP THE TABLE.

# %%
for index,dfRow in df_Measures.iterrows():
    row_key = 'measurement_{}'.format(index)
    row = RadiationMeasurements.row(row_key)
    

    for aColumn in table_columns:  #([0],[1]) maps to (columnFamily,columnName)
        row.set_cell(   
                        aColumn[0],
                        aColumn[1],
                        str(dfRow[aColumn[1]]).encode('utf-8')
                    )
    row.commit()

print('done!')
# Out:
# done!

# %%
print('Scanning 5 Measurements:')
partial_rows = RadiationMeasurements.read_rows(limit=5)
partial_rows.consume_all()
for row_key, row in partial_rows.rows.items():
    key   = row_key.decode('utf-8')
    rowArr = []
    for aColumn in table_columns:
        rowArr.append(row.cells[aColumn[0]][aColumn[1].encode("utf-8")][0].value)
    print("Key:",key)
    for i in range(len(table_columns)):
        print("Data:",table_columns[i][0],table_columns[i][1],":",rowArr[i])
# Out:
# Scanning 5 Measurements:
# Key: measurement_0
# Data: time Captured Time : b'2020-02-03 17:00:00'
# Data: time Uploaded Time : b'2020-02-03 17:00:00'
# Data: location Latitude : b'37.507551666667'
# Data: location Longitude : b'139.94117'
# Data: location Height : b''
# Data: measure Value : b'72.0'
# Data: measure Unit : b'cpm'
# Data: device Device ID : b''
# Key: measurement_1
# Data: time Captured Time : b'2020-02-03 11:00:00'
# Data: time Uploaded Time : b'2020-02-03 11:00:00'
# Data: location Latitude : b'37.505445'
# Data: location Longitude : b'0.016666666666667'
# Data: location Height : b''
# Data: measure Value : b'68.0'
# Data: measure Unit : b'cpm'
# Data: device Device ID : b''
# Key: measurement_10
# Data: time Captured Time : b'2020-01-12 19:00:00'
# Data: time Uploaded Time : b'2020-01-12 19:00:00'
# Data: location Latitude : b'37.550586666667'
# Data: location Longitude : b'139.95'
# Data: location Height : b''
# Data: measure Value : b'44.0'
# ...

# %%
print('Scanning measurement 3 to 5:')
partial_rows = RadiationMeasurements.read_rows(start_key="measurement_3",end_key="measurement_5")
partial_rows.consume_all()

for row_key, row in partial_rows.rows.items():
    key   = row_key.decode('utf-8')
    rowArr = []
    for aColumn in table_columns:
        rowArr.append(row.cells[aColumn[0]][aColumn[1].encode("utf-8")][0].value)
    print("Key:",key)
    for i in range(len(table_columns)):
        print("      Data:",table_columns[i][0],table_columns[i][1],":",rowArr[i])
# Out:
# Scanning measurement 3 to 5:
# Key: measurement_3
#       Data: time Captured Time : b'2020-02-01 03:00:00'
#       Data: time Uploaded Time : b'2020-02-01 03:00:00'
#       Data: location Latitude : b'34.066486666667'
#       Data: location Longitude : b'-118.89521666667'
#       Data: location Height : b''
#       Data: measure Value : b'50.0'
#       Data: measure Unit : b'cpm'
#       Data: device Device ID : b''
# Key: measurement_30
#       Data: time Captured Time : b'2017-12-04 00:59:39'
#       Data: time Uploaded Time : b'2017-12-04 00:59:39.193733'
#       Data: location Latitude : b'35.615814'
#       Data: location Longitude : b'139.625711'
#       Data: location Height : b'24'
#       Data: measure Value : b'15.9'
#       Data: measure Unit : b'celcius'
#       Data: device Device ID : b'100189'
# Key: measurement_300
#       Data: time Captured Time : b'2017-12-04 00:48:59'
#       Data: time Uploaded Time : b'2017-12-04 00:49:00.122824'
# ...

# %% [markdown]
# ### QUESTION:
# **_In which line are the data actually fetched from Bigtable?_** Explain briefly.

# %% [markdown]
# #### <span style="color:red">partial_rows.consume_all() this command fetches the data from the bigtable. When it is called the data for the specified range is fetched and stored in partial_rows.  </span>

# %%
print('Sum all Measurements that the unit is cpm:')


###############
####    TO DO HERE
##############
table_info = connection.table('RadiationMeasurements')
totalSum = 0

# Scan the entire table and retrieve all rows
rows = table_info.scan()

# Iterate through the rows and sum the values of "Value" column for rows with "Unit" column equal to "cpm"
for key, data in rows:
    unit = data.get(b'measure:Unit', b'').decode('utf-8')
    if unit == 'cpm':
        value = float(data.get(b'measure:Value', b'').decode('utf-8'))
        totalSum += value


print ("The sum is:", totalSum)
# Out:
# Sum all Measurements that the unit is cpm:
# The sum is: 127929.0

# %% [markdown]
# # <span style="color:#5DB664">DELETE YOUR Bigtable INSTANCE AS WHEN YOU FINISH WITH REVIEW OF THE ABOVE EXAMPLE!</span>

# %% [markdown]
# <hr style="border-top: 1px solid red; margin-top: 20px; margin-bottom: 1px"></hr>
#
# # <span style="color:RED">Exercise: </span> New York City - Buildings Dataset
#
# <hr style="border-top: 1px solid red; margin-top: 20px; margin-bottom: 1px"></hr>
#
# Similar to the example above, we are going to be using the New York City - Buildings competition dataset available [here](https://www.kaggle.com/new-york-city/nyc-buildings/data). <br>
# You should:
# 1. Download the dataset to your machine.
# 2. Create a new database.
# 3. Create the necessary tables to load the Brooklyn subset.
# 4. Load the Brooklyn dataset, but be smart when uploading. If we don't have a value for a particular cell, don't load it into Bigtable.
#
#
# ## Questions:
# 1. Report the time for loading the dataset.
# 2. Generate a report that for each zipcode displays the average of the lot and building front area. <br>
# In this query the performance is very important as you are reading a noticeable ammount of data. Come up with an initial procedure to solve the query. Later try to improve that code. Did your second implementation improve the running time? Explain why. Present the code used in both stages and the runtime for each one.

# %%
## PLACE YOUR CODE STARTING THIS POINT. 
import pandas as pd
import datetime
from time import time
import math

# %%
bk_csv= pd.read_csv("BK.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 bk_csv= pd.read_csv("BK.csv")
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
# The client must be created with admin=True because it will create a table.
client     = bigtable.Client(admin=True)
instance   = client.instance(instance_id)

# %%
table_name  = "Brooklyn_table"
table_columns = [
                    
                ]

print('Creating the {} table.'.format(table_name))

Brooklyn_table = instance.table(table_name)
Brooklyn_table.create()


columnFamilies = []
for aColumn in table_columns:
    columnFamilies.append(aColumn[0])
columnFamilies = list(set(columnFamilies))

for aColumnFamily in columnFamilies:
    cf = Brooklyn_table.column_family(aColumnFamily)
    cf.create()
     

print("done!")

# %% [markdown]
# <hr style="border-top: 5px solid orange; margin-top: 1px; margin-bottom: 1px"></hr>
